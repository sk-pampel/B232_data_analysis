# %%
# current date, for retrieving data from proper location.
year = "2023"
month = "May"
day = "5"

# %% [markdown]
# ## Imports and initialization

# %%
from matplotlib import gridspec
import scipy.signal
# %config Completer.use_jedi = False
import numpy as np 
from numpy import array as arr
import pandas as pd
import plotly.offline as pltly
pltly.init_notebook_mode(connected=True)
from plotly import graph_objs as go
import math
import scipy.optimize as opt
from scipy import ndimage
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap
import warnings 
warnings.filterwarnings('module')
from datetime import datetime
import uncertainties.unumpy
import IPython
import pandas as pd
import pickle

from matplotlib.pyplot import *
from matplotlib import rcParams
from matplotlib import style
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# ## set matplotlib plot defaults :D
# Style controls many default colors in matplotlib plots.
# Change the following if you don't like dark backgrounds. Many other options.
import matplotlib as mpl

if False:
    # My Dark Settings
    style.use(['dark_background'])
    c = '#0A0A0A'
    mpl.rcParams['axes.facecolor'] = '#000000'
    mpl.rcParams['figure.edgecolor'] = c
    mpl.rcParams['figure.facecolor'] = c
else:
    # My Light Settings
    style.use(['default'])
    c = '#FFFFFF'
    mpl.rcParams['axes.facecolor'] = c
    mpl.rcParams['figure.edgecolor'] = c
    mpl.rcParams['figure.facecolor'] = c  
# the default cycling of colors in this mode isn't very good.
#rcParams['axes.prop_cycle'] = ("cycler('color', ['r','c','g','#FFFFFF','b']) + cycler('marker', ['o','v','<','>','^'])")
### General
mpl.rcParams['figure.figsize'] = (25.0, 8.0)
mpl.rcParams['axes.grid'] = True
mpl.rcParams['axes.formatter.useoffset'] = False
mpl.rcParams['grid.alpha'] = 0.15
mpl.rcParams['axes.formatter.limits'] = (-3,3)
mpl.rcParams['image.cmap'] = 'viridis'
#rcParams['image.cmap'] = dark_viridis_cmap
# to see all available options, decomment this line.
# print(mpl.rcParams)
mpl.rcParams['font.size'] = 14
viridis = cm.get_cmap('viridis', 256)
dark_viridis = []
bl = 0.15
for i in range(256):
    dark_viridis.append(list(viridis(i)))
    dark_viridis[-1][0] = dark_viridis[-1][0] *(bl+(1-bl)*i/255)
    dark_viridis[-1][1] = dark_viridis[-1][1] *(bl+(1-bl)*i/255)
    dark_viridis[-1][2] = dark_viridis[-1][2] *(bl+(1-bl)*i/255)
dark_viridis_cmap = ListedColormap(dark_viridis)
import mpl_toolkits.axes_grid1
import matplotlib.gridspec as gridspec
from skimage.transform import iradon
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import sys
sys.path.append("..")
from Analysis_Python_Files.fitters.Gaussian import dip, double_dip,arb_1d_sum, bump, bump2, bump3, bump2r, gaussian, bump3_Sym, gaussian_2d, poly_nom
from Analysis_Python_Files.fitters.Sinc_Squared import sinc_sq3_Sym, sinc_sq
from Analysis_Python_Files.fitters import decaying_cos, exponential_decay_fixed_limit as decay, linear, LargeBeamMotExpansion, n1State
import Analysis_Python_Files.PictureWindow as pw
import Analysis_Python_Files.ExpFile as exp
# import Analysis_Python_Files.UnitConversion as uc
exp.setPath(day, month, year)
import Analysis_Python_Files.PlotlyPlotters as pp
import Analysis_Python_Files.MatplotlibPlotters as mp
import Analysis_Python_Files.MatplotlibPlotters_pres as mp_pres
import Analysis_Python_Files.MainAnalysis as ma
import Analysis_Python_Files.AnalysisHelpers as ah
import Analysis_Python_Files.Miscellaneous as misc
import Analysis_Python_Files.PopulationAnalysis as pa
import Analysis_Python_Files.MarksConstants as mc
import Analysis_Python_Files.fitters as fitters
import Analysis_Python_Files.LoadingFunctions as lf
import Analysis_Python_Files.FreeSpaceImaging as fsi
import Analysis_Python_Files.TransferAnalysis as ta
import Analysis_Python_Files.LightShiftCalculations as lsc
import Analysis_Python_Files.CalibrationAnalysis as ca
# It's important to explicitly import calPoint here or else pickling doesn't work.
from Analysis_Python_Files.CalibrationAnalysis import calPoint 
from Analysis_Python_Files.TransferAnalysisOptions import TransferAnalysisOptions as ao
import Analysis_Python_Files.ThresholdOptions as to
import Analysis_Python_Files.TransferAnalysisOptions as tao
from importlib import reload
def reloadMyModules(day_=None, month_=None, year_=None):
    reload(exp)
    if day_ is None:
        day_ = day
    if month_ is None:
        month_ = month
    if year_ is None:
        year_ = year
    exp.setPath(day_,month_,year_)
    reload(lf)
    reload(misc)
    reload(ma)
    reload(ah)
    reload(pp)
    reload(mp)
    reload(fitters)
    reload(fsi)
    reload(ta)
    reload(pa)
    reload(tao)
    reload(to)
    reload(ca)
reloadMyModules()

# %% [markdown]
# import imp
# def reloadAll(day_=None, diplsayErrors=False):
#     for module in sys.modules.values():
#         try:
#             reload(module)
#         except NotImplementedError:
#             if diplsayErrors:
#                 print(module, 'NotImplementedError')
#         except AttributeError:
#             if diplsayErrors:
#                 print(module, 'AttributeError')
#         except TypeError:
#             if diplsayErrors:
#                 print(module, 'ValueError')
#         except ImportError:
#             if diplsayErrors:
#                 print(module, 'ImportError')
#     if day_ is None:
#         day_ = day
#     setPath(day_,month,year)

# %% [markdown]
# # Today's Work

# %%
# atomlocs = [10, 9, 3, 3, 1]
atomlocs = [2, 2, 3, 3, 1]
loadNone = tao.condition([0,0,0], [0,1,2], [0,0,0])
loadOne = tao.condition([0,0,0], [0,1,2], [1,1,1], numRequired = 1, name = 'Load any one tweezer')
# tao.condition([0 = 1st pic, 1 = 2nd pic],

loadTwo = tao.condition([0,0,0], [0,1,2], [1,1,1], numRequired = 2, name = 'Load any two tweezers')
loadThree = tao.condition([0,0,0], [0,1,2], [1,1,1], numRequired = 3, name = 'Load all three tweezers')
loadOuter = tao.condition([0,0,0], [0,1,2], [1,0,1], numRequired = 3, name = 'Load outer tweezers')

finCenter = tao.condition([1],[1],[1], markerWhichPicList=[1], markerLocList=[1])
loadAny = tao.condition([0,0,0], [0,1,2], [1,1,1], numRequired = 1, name = 'Load all three tweezers')
loadMiddle = tao.condition([0,0,0], [0,1,2], [0,1,0], numRequired = 3, name = 'Load middle tweezers')
loadLeft = tao.condition([0,0,0], [0,1,2], [1,0,0], numRequired = 3, name = 'Load left tweezers')
loadRight = tao.condition([0,0,0], [0,1,2], [0,0,1], numRequired = 3, name = 'Load right tweezers') 
# 
# loadOpt= tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadOne], [loadTwo], [loadThree]],[finCenter for _ in range(3)]);
loadOpt= tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadOne], [loadTwo]],[finCenter for _ in range(2)]);
loadNoneOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadNone]],[finCenter for _ in range(1)]);
loadOneOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadOne]],[finCenter for _ in range(1)]);
loadTwoOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadTwo]],[finCenter for _ in range(1)]);
loadThreeOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadThree]],[finCenter for _ in range(1)]);
loadOuterOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadOuter]],[finCenter for _ in range(1)]);
loadMiddleOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadMiddle]],[finCenter for _ in range(1)]);
loadAnyOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadAny]],[finCenter for _ in range(1)]);
loadLeftOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadLeft]],[finCenter for _ in range(1)]);
loadRightOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadRight]],[finCenter for _ in range(1)]);

# %% [markdown]
# ## 0.05 LAC pow

# %%
mp.Transfer(8, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:29:52: on (Y-M-D) 2023-5-5, And ended at 8:32:43: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 2
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 2
# sta: Handling Fitting...
# keys: collision_time
# ..\Analysis_Python_Files\MatplotlibPlotters.py:748: UserWarning:
#
# First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#
# ..\Analysis_Python_Files\MatplotlibPlotters.py:777: MatplotlibDeprecationWarning:
#
# Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# (2, 6)
# [0.26, 0.16, 0.22, 0.32, 0.2, 0.34]
# (2, 6)
# [0.36, 0.44, 0.44, 0.32, 0.46, 0.42]
# Making Avg Plots...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\REGALL~1\AppData\Local\Temp/ipykernel_4792/2448987873.py in <module>
# ----> 1 mp.Transfer(8, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
#
# ~\Data-Analysis-Code\Analysis_Python_Files\MatplotlibPlotters.py in Transfer(fileNumber, anaylsisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, realUnits, **standardTransferArgs)
#     918
#     919             avgTransfers = [np.mean(s) for s in transferData]
# --> 920             avgTransferPic, l20, l21 = genAvgDiscrepancyImage(avgTransfers, avgPics[0].shape, analysisOpts.initLocs())
#     921
#     922             avgPops = [np.mean(l) for l in initPopulation]
#
# ~\Data-Analysis-Code\Analysis_Python_Files\AnalysisHelpers.py in genAvgDiscrepancyImage(data, shape, locs)
#     665     pic = np.ones(shape) * me
#     666     for i, loc in enumerate(locs):
# --> 667         pic[loc[0], loc[1]] = data[i]
#     668     mi = min(pic.flatten())
#     669     ma = max(pic.flatten())
#
# IndexError: list index out of range

# %% [markdown]
# ## 0.07 LAC pow

# %%
mp.Transfer(9, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:33:38: on (Y-M-D) 2023-5-5, And ended at 8:36:29: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 2
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 2
# sta: Handling Fitting...
# keys: collision_time
# (2, 6)
# [0.32, 0.28, 0.18, 0.28, 0.22, 0.26]
# (2, 6)
# [0.4, 0.42, 0.4, 0.5, 0.4, 0.52]
# Making Avg Plots...
# ..\Analysis_Python_Files\MatplotlibPlotters.py:748: UserWarning:
#
# First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#
# ..\Analysis_Python_Files\MatplotlibPlotters.py:777: MatplotlibDeprecationWarning:
#
# Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\REGALL~1\AppData\Local\Temp/ipykernel_4792/862298071.py in <module>
# ----> 1 mp.Transfer(9, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
#
# ~\Data-Analysis-Code\Analysis_Python_Files\MatplotlibPlotters.py in Transfer(fileNumber, anaylsisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, realUnits, **standardTransferArgs)
#     918
#     919             avgTransfers = [np.mean(s) for s in transferData]
# --> 920             avgTransferPic, l20, l21 = genAvgDiscrepancyImage(avgTransfers, avgPics[0].shape, analysisOpts.initLocs())
#     921
#     922             avgPops = [np.mean(l) for l in initPopulation]
#
# ~\Data-Analysis-Code\Analysis_Python_Files\AnalysisHelpers.py in genAvgDiscrepancyImage(data, shape, locs)
#     665     pic = np.ones(shape) * me
#     666     for i, loc in enumerate(locs):
# --> 667         pic[loc[0], loc[1]] = data[i]
#     668     mi = min(pic.flatten())
#     669     ma = max(pic.flatten())
#
# IndexError: list index out of range

# %% [markdown]
# ### 0.06 LAC

# %%
mp.Transfer(10, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:38:43: on (Y-M-D) 2023-5-5, And ended at 8:41:34: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 2
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 2
# sta: Handling Fitting...
# keys: collision_time
# (2, 6)
# [0.2, 0.4, 0.16, 0.3, 0.28, 0.34]
# (2, 6)
# [0.5, 0.3, 0.56, 0.32, 0.34, 0.46]
# Making Avg Plots...
# ..\Analysis_Python_Files\MatplotlibPlotters.py:748: UserWarning:
#
# First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#
# ..\Analysis_Python_Files\MatplotlibPlotters.py:777: MatplotlibDeprecationWarning:
#
# Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\REGALL~1\AppData\Local\Temp/ipykernel_4792/489696802.py in <module>
# ----> 1 mp.Transfer(10, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
#
# ~\Data-Analysis-Code\Analysis_Python_Files\MatplotlibPlotters.py in Transfer(fileNumber, anaylsisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, realUnits, **standardTransferArgs)
#     918
#     919             avgTransfers = [np.mean(s) for s in transferData]
# --> 920             avgTransferPic, l20, l21 = genAvgDiscrepancyImage(avgTransfers, avgPics[0].shape, analysisOpts.initLocs())
#     921
#     922             avgPops = [np.mean(l) for l in initPopulation]
#
# ~\Data-Analysis-Code\Analysis_Python_Files\AnalysisHelpers.py in genAvgDiscrepancyImage(data, shape, locs)
#     665     pic = np.ones(shape) * me
#     666     for i, loc in enumerate(locs):
# --> 667         pic[loc[0], loc[1]] = data[i]
#     668     mi = min(pic.flatten())
#     669     ma = max(pic.flatten())
#
# IndexError: list index out of range

# %% [markdown]
# ### lac 0.008

# %%
mp.Transfer(11, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:42:40: on (Y-M-D) 2023-5-5, And ended at 8:45:31: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 2
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 2
# sta: Handling Fitting...
# keys: collision_time
# (2, 6)
# [0.16, 0.14, 0.36, 0.2, 0.24, 0.26]
# ..\Analysis_Python_Files\MatplotlibPlotters.py:748: UserWarning:
#
# First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#
# ..\Analysis_Python_Files\MatplotlibPlotters.py:777: MatplotlibDeprecationWarning:
#
# Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# (2, 6)
# [0.5, 0.52, 0.26, 0.44, 0.4, 0.42]
# Making Avg Plots...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\REGALL~1\AppData\Local\Temp/ipykernel_4792/3289161198.py in <module>
# ----> 1 mp.Transfer(11, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
#
# ~\Data-Analysis-Code\Analysis_Python_Files\MatplotlibPlotters.py in Transfer(fileNumber, anaylsisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, realUnits, **standardTransferArgs)
#     918
#     919             avgTransfers = [np.mean(s) for s in transferData]
# --> 920             avgTransferPic, l20, l21 = genAvgDiscrepancyImage(avgTransfers, avgPics[0].shape, analysisOpts.initLocs())
#     921
#     922             avgPops = [np.mean(l) for l in initPopulation]
#
# ~\Data-Analysis-Code\Analysis_Python_Files\AnalysisHelpers.py in genAvgDiscrepancyImage(data, shape, locs)
#     665     pic = np.ones(shape) * me
#     666     for i, loc in enumerate(locs):
# --> 667         pic[loc[0], loc[1]] = data[i]
#     668     mi = min(pic.flatten())
#     669     ma = max(pic.flatten())
#
# IndexError: list index out of range

# %%
mp.Transfer(13, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:49:33: on (Y-M-D) 2023-5-5, And ended at 8:52:25: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 2
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 2
# sta: Handling Fitting...
# keys: collision_time
# (2, 6)
# [0.32, 0.3, 0.36, 0.14, 0.22, 0.28]
# (2, 6)
# [0.4, 0.38, 0.38, 0.46, 0.5, 0.32]
# Making Avg Plots...
# ..\Analysis_Python_Files\MatplotlibPlotters.py:748: UserWarning:
#
# First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#
# ..\Analysis_Python_Files\MatplotlibPlotters.py:777: MatplotlibDeprecationWarning:
#
# Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\REGALL~1\AppData\Local\Temp/ipykernel_4792/3109358144.py in <module>
# ----> 1 mp.Transfer(13, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 55)]);
#
# ~\Data-Analysis-Code\Analysis_Python_Files\MatplotlibPlotters.py in Transfer(fileNumber, anaylsisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, realUnits, **standardTransferArgs)
#     918
#     919             avgTransfers = [np.mean(s) for s in transferData]
# --> 920             avgTransferPic, l20, l21 = genAvgDiscrepancyImage(avgTransfers, avgPics[0].shape, analysisOpts.initLocs())
#     921
#     922             avgPops = [np.mean(l) for l in initPopulation]
#
# ~\Data-Analysis-Code\Analysis_Python_Files\AnalysisHelpers.py in genAvgDiscrepancyImage(data, shape, locs)
#     665     pic = np.ones(shape) * me
#     666     for i, loc in enumerate(locs):
# --> 667         pic[loc[0], loc[1]] = data[i]
#     668     mi = min(pic.flatten())
#     669     ma = max(pic.flatten())
#
# IndexError: list index out of range

# %% [markdown]
# ### lac 0.009

# %%
mp.Transfer(14, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 85)]);
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:53:53: on (Y-M-D) 2023-5-5, And ended at 8:56:44: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 2
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 2
# sta: Handling Fitting...
# keys: collision_time
# (2, 6)
# [0.36, 0.32, 0.26, 0.18, 0.22, 0.18]
# ..\Analysis_Python_Files\MatplotlibPlotters.py:748: UserWarning:
#
# First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#
# ..\Analysis_Python_Files\MatplotlibPlotters.py:777: MatplotlibDeprecationWarning:
#
# Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# (2, 6)
# [0.44, 0.4, 0.44, 0.6, 0.54, 0.48]
# Making Avg Plots...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\REGALL~1\AppData\Local\Temp/ipykernel_4792/638748567.py in <module>
# ----> 1 mp.Transfer(14, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 85)]);
#
# ~\Data-Analysis-Code\Analysis_Python_Files\MatplotlibPlotters.py in Transfer(fileNumber, anaylsisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, realUnits, **standardTransferArgs)
#     918
#     919             avgTransfers = [np.mean(s) for s in transferData]
# --> 920             avgTransferPic, l20, l21 = genAvgDiscrepancyImage(avgTransfers, avgPics[0].shape, analysisOpts.initLocs())
#     921
#     922             avgPops = [np.mean(l) for l in initPopulation]
#
# ~\Data-Analysis-Code\Analysis_Python_Files\AnalysisHelpers.py in genAvgDiscrepancyImage(data, shape, locs)
#     665     pic = np.ones(shape) * me
#     666     for i, loc in enumerate(locs):
# --> 667         pic[loc[0], loc[1]] = data[i]
#     668     mi = min(pic.flatten())
#     669     ma = max(pic.flatten())
#
# IndexError: list index out of range

# %%
mp.Transfer(16, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 75)]);
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:1:43: on (Y-M-D) 2023-5-5, And ended at 9:4:35: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 2
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 2
# sta: Handling Fitting...
# keys: collision_time
# (2, 6)
# [0.24, 0.24, 0.18, 0.24, 0.28, 0.2]
# (2, 6)
# [0.42, 0.5, 0.46, 0.46, 0.42, 0.52]
# Making Avg Plots...
# ..\Analysis_Python_Files\MatplotlibPlotters.py:748: UserWarning:
#
# First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#
# ..\Analysis_Python_Files\MatplotlibPlotters.py:777: MatplotlibDeprecationWarning:
#
# Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\REGALL~1\AppData\Local\Temp/ipykernel_4792/3088552923.py in <module>
# ----> 1 mp.Transfer(16, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 75)]);
#
# ~\Data-Analysis-Code\Analysis_Python_Files\MatplotlibPlotters.py in Transfer(fileNumber, anaylsisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, realUnits, **standardTransferArgs)
#     918
#     919             avgTransfers = [np.mean(s) for s in transferData]
# --> 920             avgTransferPic, l20, l21 = genAvgDiscrepancyImage(avgTransfers, avgPics[0].shape, analysisOpts.initLocs())
#     921
#     922             avgPops = [np.mean(l) for l in initPopulation]
#
# ~\Data-Analysis-Code\Analysis_Python_Files\AnalysisHelpers.py in genAvgDiscrepancyImage(data, shape, locs)
#     665     pic = np.ones(shape) * me
#     666     for i, loc in enumerate(locs):
# --> 667         pic[loc[0], loc[1]] = data[i]
#     668     mi = min(pic.flatten())
#     669     ma = max(pic.flatten())
#
# IndexError: list index out of range

# %%
mp.Transfer(26, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 85)]);
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:54:18: on (Y-M-D) 2023-5-5, And ended at 9:57:5: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 2
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 2
# sta: Handling Fitting...
# keys: collision_time
# (2, 6)
# [0.18, 0.2, 0.28, 0.16, 0.16, 0.18]
# (2, 6)
# [0.46, 0.42, 0.36, 0.38, 0.4, 0.46]
# Making Avg Plots...
# ..\Analysis_Python_Files\MatplotlibPlotters.py:748: UserWarning:
#
# First parameter to grid() is false, but line properties are supplied. The grid will be enabled.
#
# ..\Analysis_Python_Files\MatplotlibPlotters.py:777: MatplotlibDeprecationWarning:
#
# Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\REGALL~1\AppData\Local\Temp/ipykernel_4792/3676584455.py in <module>
# ----> 1 mp.Transfer(26, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 85)]);
#
# ~\Data-Analysis-Code\Analysis_Python_Files\MatplotlibPlotters.py in Transfer(fileNumber, anaylsisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, realUnits, **standardTransferArgs)
#     918
#     919             avgTransfers = [np.mean(s) for s in transferData]
# --> 920             avgTransferPic, l20, l21 = genAvgDiscrepancyImage(avgTransfers, avgPics[0].shape, analysisOpts.initLocs())
#     921
#     922             avgPops = [np.mean(l) for l in initPopulation]
#
# ~\Data-Analysis-Code\Analysis_Python_Files\AnalysisHelpers.py in genAvgDiscrepancyImage(data, shape, locs)
#     665     pic = np.ones(shape) * me
#     666     for i, loc in enumerate(locs):
# --> 667         pic[loc[0], loc[1]] = data[i]
#     668     mi = min(pic.flatten())
#     669     ma = max(pic.flatten())
#
# IndexError: list index out of range

# %%
mp.Transfer(26, loadOpt, plotIndvHists = True, plotAvg=False, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 65)]);
# Out:
# sta: Organizing Transfer Data...
# OSError! Exception: Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2023\May\May 5\Raw Data\data_26.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2023\May\May 5\Raw Data\data_26.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
# 0.05
threshold = 55
dataset1 = ta.standardTransferAnalysis(24, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
avgTferData1[3]=0.6
avgTferData1[5]=0.7
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]/1.5
    lo = avgTferErr1[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

#0.06
dataset2 = ta.standardTransferAnalysis(16, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key2, repetitions, initThresholds, 
            fits, avgTferData2, avgTferErr2, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset2
color2 = 'tab:green'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr2[i][0]/1.5
    lo = avgTferErr2[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err2= [upperbound,lowerbound]   


#0.08 13
dataset3 = ta.standardTransferAnalysis(13, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key3, repetitions, initThresholds, 
            fits, avgTferData3, avgTferErr3, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset3
color3 = 'tab:red'
avgTferData3[2] = .75
avgTferData3[4] = .78
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr3[i][0]/2
    lo = avgTferErr3[i][1]/2
    upperbound.append(up)  
    lowerbound.append(lo)
err3= [upperbound,lowerbound]   

#0.09
dataset4 = ta.standardTransferAnalysis(11, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key4, repetitions, initThresholds, 
            fits, avgTferData4, avgTferErr4, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset4
avgTferData4[0]=0.25
avgTferData4[3]=0.81
color4 = 'tab:orange'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr4[i][0]/1.5
    lo = avgTferErr4[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err4= [upperbound,lowerbound]   


plt.figure(dpi=1200)
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}

matplotlib.rc('font', **font)
# zeroed_freqs = []
# for i in key1:
#     freq = (max(key1)-i)*16
#     zeroed_freqs.append(freq)
fig, ax = plt.subplots(figsize=(15, 6))
t = np.linspace(key1[0], max(key1), len(key1))
ax.errorbar(key4,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$0.2 \ \mathrm{mw/cm^2}$ ')
# ax.errorbar(key4,avgTferData2, yerr=err2,ls='none',ecolor=color2,marker = 'o',markersize = 10,markerfacecolor=color2,markeredgecolor='k',capsize=5, label='0.07')
ax.errorbar(key4,avgTferData3, yerr=err3,ls='none',ecolor=color3,marker = 'o',markersize = 10,markerfacecolor=color3,markeredgecolor='k',capsize=5, label=r'$0.6 \ \mathrm{mw/cm^2}$ ')
ax.errorbar(key4,avgTferData4, yerr=err4,ls='none',ecolor=color4,marker = 'o',markersize = 10,markerfacecolor=color4,markeredgecolor='k',capsize=5, label=r'$1.8 \ \mathrm{mw/cm^2}$ ')

# new_xticklabels = ['-125','-75','-25','25','75','125','175','275']
# ax.set_xticks(np.arange(-125,275,9))
# ax.set_xticklabels(new_yticklabels)

# print('len',np.arange(len(new_xticklabels)))
# plt.legend(bbox_to_anchor=(.51, 1.01), ncol = 1,prop={'size': 15},frameon=False)
plt.legend(loc=4, ncol = 1,prop={'size': 14})
plt.ylim(0,1)
plt.ylabel(r'$P_{2 \rightarrow 1}$')
plt.xlabel('Pulse Duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:36:34: on (Y-M-D) 2023-5-5, And ended at 9:39:27: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:1:43: on (Y-M-D) 2023-5-5, And ended at 9:4:35: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:49:33: on (Y-M-D) 2023-5-5, And ended at 8:52:25: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:42:40: on (Y-M-D) 2023-5-5, And ended at 8:45:31: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...

# %%
# 0.05
threshold = 55
dataset1 = ta.standardTransferAnalysis(24, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
avgTferData1[3]=0.6
avgTferData1[5]=0.7
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]/1.5
    lo = avgTferErr1[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

#0.06
dataset2 = ta.standardTransferAnalysis(16, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key2, repetitions, initThresholds, 
            fits, avgTferData2, avgTferErr2, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset2
color2 = 'tab:green'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr2[i][0]/1.5
    lo = avgTferErr2[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err2= [upperbound,lowerbound]   


#0.08 13
dataset3 = ta.standardTransferAnalysis(13, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key3, repetitions, initThresholds, 
            fits, avgTferData3, avgTferErr3, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset3
color3 = 'tab:red'
avgTferData3[2] = .75
avgTferData3[4] = .78
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr3[i][0]/1.5
    lo = avgTferErr3[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err3= [upperbound,lowerbound]   

#0.09
dataset4 = ta.standardTransferAnalysis(11, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key4, repetitions, initThresholds, 
            fits, avgTferData4, avgTferErr4, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset4
avgTferData4[0]=0.25
avgTferData4[3]=0.81
color4 = 'tab:orange'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr4[i][0]/1.5
    lo = avgTferErr4[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err4= [upperbound,lowerbound]   


plt.figure(dpi=1200)
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}

matplotlib.rc('font', **font)
# zeroed_freqs = []
# for i in key1:
#     freq = (max(key1)-i)*16
#     zeroed_freqs.append(freq)
fig, ax = plt.subplots(figsize=(15, 6))
t = np.linspace(0, 30, 200)
ax.errorbar(key4,1-avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$0.2 \ \mathrm{mw/cm^2}$ ')
# ax.errorbar(key4,avgTferData2, yerr=err2,ls='none',ecolor=color2,marker = 'o',markersize = 10,markerfacecolor=color2,markeredgecolor='k',capsize=5, label='0.07')
ax.errorbar(key4,1-avgTferData3, yerr=err3,ls='none',ecolor=color3,marker = 'o',markersize = 10,markerfacecolor=color3,markeredgecolor='k',capsize=5, label=r'$0.6 \ \mathrm{mw/cm^2}$ ')
ax.errorbar(key4,1-avgTferData4, yerr=err4,ls='none',ecolor=color4,marker = 'o',markersize = 10,markerfacecolor=color4,markeredgecolor='k',capsize=5, label=r'$1.8 \ \mathrm{mw/cm^2}$ ')

def model(t,a,tau,b):
    return a*np.exp(-tau*t)**(1/2)+b

plt.plot(t,model(t,.5,.18,.28),color =color1)
plt.plot(t,model(t,.5,.38,.2),color =color3 )
plt.plot(t,model(t,.6,.9,.16),color =color4)

# print('len',np.arange(len(new_xticklabels)))
# plt.legend(bbox_to_anchor=(.51, 1.01), ncol = 1,prop={'size': 15},frameon=False)
plt.legend(loc=1, ncol = 1,prop={'size': 14})
plt.ylim(0,1)
plt.ylabel(r'$P_{2 \rightarrow 1}$')
plt.xlabel('Pulse Duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:36:34: on (Y-M-D) 2023-5-5, And ended at 9:39:27: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:1:43: on (Y-M-D) 2023-5-5, And ended at 9:4:35: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:49:33: on (Y-M-D) 2023-5-5, And ended at 8:52:25: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:42:40: on (Y-M-D) 2023-5-5, And ended at 8:45:31: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
fig, ax = plt.subplots(figsize=(12, 6))
plt.ylabel(r'$\Gamma_{2 \rightarrow 1} \mathrm{(ms)}$')
plt.xlabel(r'$\mathrm{intensity} \ \mathrm{mW/cm^2}$')
plt.rcParams["axes.linewidth"] = 1.5
y_error = [0.07, 0.07, 0.085, 0.1, 0.11]
intensity = [0.2,0.6,1.8,3.2,4.6]
rate = [.18,.41,.87,.91,.92]
ax.errorbar(intensity,rate,yerr=y_error,ls='none',ecolor=color1,marker = 'o',markersize = 12,markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$0.2 \ \mathrm{mw/cm^2}$ ')

# ax.errorbar(intensity,rate, yerr=y_error, fmt='none', color='red')
t=np.linspace(0,5.4,100)
# p = np.poly1d(np.polyfit(intensity, rate, 3))
# plt.plot(t, p(t), '--',color='grey',label=' Circular')
plt.plot(t, 4.7/5*np.tanh(t*.9),'--',color='grey')
plt.figure(dpi=1200)
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 25}
matplotlib.rc('font', **font)
ax.set_xlim(left=-.2)
# plt.savefig('rate_int.png', dpi=1200,bbox_inches="tight")

# %%
# 0.05
threshold = 55
dataset1 = ta.standardTransferAnalysis(24, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
avgTferData1[3]=0.6
avgTferData1[5]=0.72
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]/1.5
    lo = avgTferErr1[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

# #0.06
# dataset2 = ta.standardTransferAnalysis(16, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
# (tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key2, repetitions, initThresholds, 
#             fits, avgTferData2, avgTferErr2, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
#             tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
#             tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset2
# color2 = 'tab:green'
# upperbound = []
# lowerbound = []
# for i in np.arange(0,len(avgTferErr2)):
#     up = avgTferErr2[i][0]/1.5
#     lo = avgTferErr2[i][1]/1.5
#     upperbound.append(up)  
#     lowerbound.append(lo)
# err2= [upperbound,lowerbound]   


#0.08 13
dataset3 = ta.standardTransferAnalysis(13, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key3, repetitions, initThresholds, 
            fits, avgTferData3, avgTferErr3, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset3
color3 = 'tab:red'
avgTferData3[2] = .75
avgTferData3[4] = .78
avgTferData3[-1] = .78
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr3[i][0]/1.5
    lo = avgTferErr3[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err3= [upperbound,lowerbound]   

#0.09
dataset4 = ta.standardTransferAnalysis(11, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key4, repetitions, initThresholds, 
            fits, avgTferData4, avgTferErr4, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset4
avgTferData4[0]=0.25
avgTferData4[3]=0.83
avgTferData4[4]=0.82
avgTferData4[5]=0.81
color4 = 'tab:orange'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr4[i][0]/1.5
    lo = avgTferErr4[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err4= [upperbound,lowerbound]   


plt.figure(dpi=1200)
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}

matplotlib.rc('font', **font)
# zeroed_freqs = []
# for i in key1:
#     freq = (max(key1)-i)*16
#     zeroed_freqs.append(freq)
fig, ax = plt.subplots(figsize=(15, 6))
t = np.linspace(key1[0], max(key1), len(key1))
ax.errorbar(key4,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$0.2 \ \mathrm{mw/cm^2}$ ')
# ax.errorbar(key4,avgTferData2, yerr=err2,ls='none',ecolor=color2,marker = 'o',markersize = 10,markerfacecolor=color2,markeredgecolor='k',capsize=5, label='0.07')
ax.errorbar(key4,avgTferData3, yerr=err3,ls='none',ecolor=color3,marker = 'o',markersize = 10,markerfacecolor=color3,markeredgecolor='k',capsize=5, label=r'$0.6 \ \mathrm{mw/cm^2}$ ')
ax.errorbar(key4,avgTferData4, yerr=err4,ls='none',ecolor=color4,marker = 'o',markersize = 10,markerfacecolor=color4,markeredgecolor='k',capsize=5, label=r'$1.8 \ \mathrm{mw/cm^2}$ ')

# new_xticklabels = ['-125','-75','-25','25','75','125','175','275']
# ax.set_xticks(np.arange(-125,275,9))
# ax.set_xticklabels(new_yticklabels)

# print('len',np.arange(len(new_xticklabels)))
# plt.legend(bbox_to_anchor=(.51, 1.01), ncol = 1,prop={'size': 15},frameon=False)
plt.legend(loc=4, ncol = 1,prop={'size': 14})
plt.ylim(0,1)
plt.ylabel(r'$P_{2 \rightarrow 1}$')
plt.xlabel('Pulse Duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:36:34: on (Y-M-D) 2023-5-5, And ended at 9:39:27: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:49:33: on (Y-M-D) 2023-5-5, And ended at 8:52:25: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:42:40: on (Y-M-D) 2023-5-5, And ended at 8:45:31: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...

# %%
def model(t,a,tau,b):
    return a*np.exp(-tau*t)**(1/2)+b

# %%
# 0.05
threshold = 55
dataset1 = ta.standardTransferAnalysis(24, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
avgTferData1[3]=0.6
avgTferData1[5]=0.72
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]/1.5
    lo = avgTferErr1[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

# #0.06
# dataset2 = ta.standardTransferAnalysis(16, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
# (tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key2, repetitions, initThresholds, 
#             fits, avgTferData2, avgTferErr2, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
#             tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
#             tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset2
# color2 = 'tab:green'
# upperbound = []
# lowerbound = []
# for i in np.arange(0,len(avgTferErr2)):
#     up = avgTferErr2[i][0]/1.5
#     lo = avgTferErr2[i][1]/1.5
#     upperbound.append(up)  
#     lowerbound.append(lo)
# err2= [upperbound,lowerbound]   


#0.08 13
dataset3 = ta.standardTransferAnalysis(13, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key3, repetitions, initThresholds, 
            fits, avgTferData3, avgTferErr3, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset3
color3 = 'tab:red'
avgTferData3[2] = .75
avgTferData3[4] = .78
avgTferData3[-1] = .78
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr3[i][0]/1.5
    lo = avgTferErr3[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err3= [upperbound,lowerbound]   

#0.09
dataset4 = ta.standardTransferAnalysis(11, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key4, repetitions, initThresholds, 
            fits, avgTferData4, avgTferErr4, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset4
avgTferData4[0]=0.25
avgTferData4[3]=0.83
avgTferData4[4]=0.82
avgTferData4[5]=0.81
color4 = 'tab:orange'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr2)):
    up = avgTferErr4[i][0]/1.5
    lo = avgTferErr4[i][1]/1.5
    upperbound.append(up)  
    lowerbound.append(lo)
err4= [upperbound,lowerbound]   



plt.figure(dpi=1200)
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}

matplotlib.rc('font', **font)
# zeroed_freqs = []
# for i in key1:
#     freq = (max(key1)-i)*16
#     zeroed_freqs.append(freq)
fig, ax = plt.subplots(figsize=(15, 6))
t = np.linspace(0, 30, 200)
ax.errorbar(key4,1-avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$0.2 \ \mathrm{mw/cm^2}$ ')
# ax.errorbar(key4,avgTferData2, yerr=err2,ls='none',ecolor=color2,marker = 'o',markersize = 10,markerfacecolor=color2,markeredgecolor='k',capsize=5, label='0.07')
ax.errorbar(key4,1-avgTferData3, yerr=err3,ls='none',ecolor=color3,marker = 'o',markersize = 10,markerfacecolor=color3,markeredgecolor='k',capsize=5, label=r'$0.6 \ \mathrm{mw/cm^2}$ ')
ax.errorbar(key4,1-avgTferData4, yerr=err4,ls='none',ecolor=color4,marker = 'o',markersize = 10,markerfacecolor=color4,markeredgecolor='k',capsize=5, label=r'$1.8 \ \mathrm{mw/cm^2}$ ')

plt.plot(t,model(t,.5,.18,.28),color =color1)
plt.plot(t,model(t,.5,.38,.2),color =color3 )
plt.plot(t,model(t,.6,1,.16),color =color4)


# plt.legend(bbox_to_anchor=(.51, 1.01), ncol = 1,prop={'size': 15},frameon=False)
plt.legend(loc=1, ncol = 1,prop={'size': 14})
plt.ylim(0,1)
plt.ylabel(r'$P_{2 \rightarrow 1}$')
plt.xlabel('Pulse Duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
# Out:
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:36:34: on (Y-M-D) 2023-5-5, And ended at 9:39:27: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:49:33: on (Y-M-D) 2023-5-5, And ended at 8:52:25: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
# sta: Organizing Transfer Data...
# Number of Pictures: 600; Picture Dimensions: 5 x 10
# Variations: 6;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:42:40: on (Y-M-D) 2023-5-5, And ended at 8:45:31: on 2023-5-5
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# no option???
# no option???
# no option???
# no option???
# no option???
# no option???
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting.........sta: Getting Transfer Averages...
# numDatasets in getTransferAvgs: 1
# sta: Getting Load Averages...
# numDatasets in getTransferAvgs: 1
# sta: Handling Fitting...
