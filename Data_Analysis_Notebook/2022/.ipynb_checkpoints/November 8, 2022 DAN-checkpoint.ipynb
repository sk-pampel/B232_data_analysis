# %% [markdown]
# # November 7, 2022 Data Analysis Notebook

# %%
# current date, for retrieving data from proper location.
year = "2022"
month = "November"
day = "7"

# %% [markdown]
# ## Imports and initialization

# %%
from matplotlib import gridspec

# %%
import scipy.signal

# %%
# %config Completer.use_jedi = False
import numpy as np 
from numpy import array as arr
import pandas as pd
import plotly.offline as pltly
pltly.init_notebook_mode(connected=True)
from plotly import graph_objs as go
import math
import scipy.optimize as opt
from scipy import ndimage
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap
import warnings 
warnings.filterwarnings('module')
from datetime import datetime
import uncertainties.unumpy
import IPython
import pandas as pd
import pickle

from matplotlib.pyplot import *
from matplotlib import rcParams
from matplotlib import style
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# ## set matplotlib plot defaults :D
# Style controls many default colors in matplotlib plots.
# Change the following if you don't like dark backgrounds. Many other options.
import matplotlib as mpl

if False:
    # My Dark Settings
    style.use(['dark_background'])
    c = '#0A0A0A'
    mpl.rcParams['axes.facecolor'] = '#000000'
    mpl.rcParams['figure.edgecolor'] = c
    mpl.rcParams['figure.facecolor'] = c
else:
    # My Light Settings
    style.use(['default'])
    c = '#FFFFFF'
    mpl.rcParams['axes.facecolor'] = c
    mpl.rcParams['figure.edgecolor'] = c
    mpl.rcParams['figure.facecolor'] = c  
# the default cycling of colors in this mode isn't very good.
#rcParams['axes.prop_cycle'] = ("cycler('color', ['r','c','g','#FFFFFF','b']) + cycler('marker', ['o','v','<','>','^'])")
### General
mpl.rcParams['figure.figsize'] = (25.0, 8.0)
mpl.rcParams['axes.grid'] = True
mpl.rcParams['axes.formatter.useoffset'] = False
mpl.rcParams['grid.alpha'] = 0.15
mpl.rcParams['axes.formatter.limits'] = (-3,3)
mpl.rcParams['image.cmap'] = 'viridis'
#rcParams['image.cmap'] = dark_viridis_cmap
# to see all available options, decomment this line.
# print(mpl.rcParams)
mpl.rcParams['font.size'] = 14
viridis = cm.get_cmap('viridis', 256)
dark_viridis = []
bl = 0.15
for i in range(256):
    dark_viridis.append(list(viridis(i)))
    dark_viridis[-1][0] = dark_viridis[-1][0] *(bl+(1-bl)*i/255)
    dark_viridis[-1][1] = dark_viridis[-1][1] *(bl+(1-bl)*i/255)
    dark_viridis[-1][2] = dark_viridis[-1][2] *(bl+(1-bl)*i/255)
dark_viridis_cmap = ListedColormap(dark_viridis)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.2.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import mpl_toolkits.axes_grid1
import matplotlib.gridspec as gridspec
from skimage.transform import iradon

# %%
dark_viridis_cmap

# %%
import sys
sys.path.append("..")
from Analysis_Python_Files.fitters.Gaussian import dip, double_dip, bump, bump2, bump3, bump2r, gaussian, bump3_Sym, gaussian_2d
from Analysis_Python_Files.fitters.Sinc_Squared import sinc_sq3_Sym, sinc_sq
from Analysis_Python_Files.fitters import decaying_cos, exponential_decay_fixed_limit as decay, linear, LargeBeamMotExpansion, n1State
import Analysis_Python_Files.PictureWindow as pw
import Analysis_Python_Files.ExpFile as exp
exp.setPath(day, month, year)
import Analysis_Python_Files.PlotlyPlotters as pp
import Analysis_Python_Files.MatplotlibPlotters as mp
import Analysis_Python_Files.MainAnalysis as ma
import Analysis_Python_Files.AnalysisHelpers as ah
import Analysis_Python_Files.Miscellaneous as misc
import Analysis_Python_Files.PopulationAnalysis as pa
import Analysis_Python_Files.MarksConstants as mc
import Analysis_Python_Files.fitters as fitters
import Analysis_Python_Files.LoadingFunctions as lf
import Analysis_Python_Files.FreeSpaceImaging as fsi
import Analysis_Python_Files.TransferAnalysis as ta
import Analysis_Python_Files.LightShiftCalculations as lsc
import Analysis_Python_Files.CalibrationAnalysis as ca
# It's important to explicitly import calPoint here or else pickling doesn't work.
from Analysis_Python_Files.CalibrationAnalysis import calPoint 
from Analysis_Python_Files.TransferAnalysisOptions import TransferAnalysisOptions as ao
import Analysis_Python_Files.ThresholdOptions as to
import Analysis_Python_Files.TransferAnalysisOptions as tao

# %% [markdown]
# import imp
# def reloadAll(day_=None, diplsayErrors=False):
#     for module in sys.modules.values():
#         try:
#             reload(module)
#         except NotImplementedError:
#             if diplsayErrors:
#                 print(module, 'NotImplementedError')
#         except AttributeError:
#             if diplsayErrors:
#                 print(module, 'AttributeError')
#         except TypeError:
#             if diplsayErrors:
#                 print(module, 'ValueError')
#         except ImportError:
#             if diplsayErrors:
#                 print(module, 'ImportError')
#     if day_ is None:
#         day_ = day
#     setPath(day_,month,year)

# %%
from importlib import reload
def reloadMyModules(day_=None, month_=None, year_=None):
    reload(exp)
    if day_ is None:
        day_ = day
    if month_ is None:
        month_ = month
    if year_ is None:
        year_ = year
    exp.setPath(day_,month_,year_)
    reload(lf)
    reload(misc)
    reload(ma)
    reload(ah)
    reload(pp)
    reload(mp)
    reload(fitters)
    reload(fsi)
    reload(ta)
    reload(pa)
    reload(tao)
    reload(to)
    reload(ca)
reloadMyModules()

# %% [markdown]
# ## Standard Calibrations

# %% [markdown]
# ### Temperature

# %% [markdown]
# #### Running Temperature

# %%
reload(ca)
cTemps, cTimes = ca.loadAllTemperatureData()
legends = ['1: Master Computer', '2: B236', '3: Auxiliary Table', '4: Main Exp. (Near Ion Pump)']
fig, ax = plt.subplots(figsize=(20,10))
for temp,lab in zip(misc.transpose(cTemps), legends):
    ax.plot(cTimes,temp, label=lab, alpha=0.5, linewidth=1)
ax.legend()
ax.set_title('Lab Temperature Record');
ax.set_ylim(20,30)
# Out:
#  2020
# January, February, March, April, May, June, July, August, September, October, November, December,
#  2021
# January, February, March, April, May, June, July, August, September, October, November, December,
# (20.0, 30.0)

# %%
fig, ax = plt.subplots()
for temp,lab in zip(misc.transpose(cTemps), legends):
    ax.plot(cTimes[-50000:],temp[-50000:], label=lab, alpha=0.5, linewidth=1)

# %% [markdown]
# #### Today's Temperature

# %% [markdown]
# ## individual calibrations

# %%
sCalData = ca.std_analyzeAll_values()
# Out:
# ### MOT_NUMBER
# ### MOT_TEMPERATURE
# ### RED_PGC_TEMPERATURE
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\MOT_TEMPERATURE.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\MOT_TEMPERATURE.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\RED_PGC_TEMPERATURE.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\RED_PGC_TEMPERATURE.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### GREY_MOLASSES_TEMPERATURE
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\GREY_MOLASSES_TEMPERATURE.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\GREY_MOLASSES_TEMPERATURE.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### BASIC_SINGLE_ATOMS
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\BASIC_SINGLE_ATOMS.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\BASIC_SINGLE_ATOMS.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### 3DSBC_TOP_CARRIER_RAMAN_SPECTROSCOPY
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\3DSBC_TOP_CARRIER_RAMAN_SPECTROSCOPY.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\3DSBC_TOP_CARRIER_RAMAN_SPECTROSCOPY.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### THERMAL_TOP_SIDEBAND_RAMAN_SPECTROSCOPY
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\THERMAL_TOP_SIDEBAND_RAMAN_SPECTROSCOPY.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\THERMAL_TOP_SIDEBAND_RAMAN_SPECTROSCOPY.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### 3DSBC_AXIAL_RAMAN_SPECTROSCOPY
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\3DSBC_AXIAL_RAMAN_SPECTROSCOPY.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\3DSBC_AXIAL_RAMAN_SPECTROSCOPY.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### 3DSBC_TOP_SIDEBAND_RAMAN_SPECTROSCOPY
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\3DSBC_TOP_SIDEBAND_RAMAN_SPECTROSCOPY.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\3DSBC_TOP_SIDEBAND_RAMAN_SPECTROSCOPY.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### DEPTH_MEASUREMENT_DEEP
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\DEPTH_MEASUREMENT_DEEP.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\DEPTH_MEASUREMENT_DEEP.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### DEPTH_MEASUREMENT_SHALLOW
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\DEPTH_MEASUREMENT_SHALLOW.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\DEPTH_MEASUREMENT_SHALLOW.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# ### LIFETIME_MEASUREMENT
# Failed to open file! file address was "\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\LIFETIME_MEASUREMENT.h5". OSError: Unable to open file (unable to open file: name = '\\REGALB232EXP\\Local_Data_Repository\2022\October\October 27\Raw Data\LIFETIME_MEASUREMENT.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
# MOT temp = None
# PGC temp = None
# LGM temp = None
# Thermal Nbar = None
# Radial Nbar = None
# Axial Nbar = None
# Lifetime = None

# %%
with open(exp.dataAddress + 'CalibrationData.p','wb') as calFile:
    pickle.dump(sCalData, calFile)

# %% [markdown]
# ## Calibration Summmary

# %%
# load all past calibration data into a bigger strucutre.
reloadMyModules()
calData = ca.loadAllCalData()
reloadMyModules(day_=day)
# Out:
# 2020
# january,february,march,april,may,june,july,august,september,october,november,december,2021
# january,february,march,april,may,june,july,august,september,october,november,december,

# %%
reload(ca)
ca.checkData(calData)
# Out:
# Data with no error:
# 	 ['IndvRamanDepths', calPoint(value=-0.4519080874389058, error=nan, timestamp=datetime.datetime(2021, 8, 30, 5, 13, 34))]
# 	 ['IndvRamanDepths', calPoint(value=-1.5232093304584502, error=nan, timestamp=datetime.datetime(2021, 8, 30, 5, 13, 34))]
# 	 ['IndvRamanDepths', calPoint(value=-1.5232093304584502, error=nan, timestamp=datetime.datetime(2021, 8, 30, 5, 13, 34))]
# 	 ['IndvRamanDepths', calPoint(value=-1.5232093304584502, error=nan, timestamp=datetime.datetime(2021, 8, 30, 5, 13, 34))]
# 	 ['IndvRamanDepths', calPoint(value=-1.5232093304584502, error=nan, timestamp=datetime.datetime(2021, 8, 30, 5, 13, 34))]
# Suspicious MOT Temperature data ;	Reasonable data bounds: [10, 350] 	Reasonable Error: 110
# 	 calPoint(value=8.431546986673959e-05, error=0.002708755387217938, timestamp=datetime.datetime(2021, 8, 17, 4, 10, 25))
# 	 calPoint(value=0.00010093354600759849, error=0.006110134419827993, timestamp=datetime.datetime(2021, 8, 30, 4, 10, 6))
# 	 calPoint(value=6.349992813053491e-05, error=0.0007046082997992689, timestamp=datetime.datetime(2021, 9, 13, 4, 15, 39))
# Suspicious RPGC Temperature data ;	Reasonable data bounds: [3, 50] 	Reasonable Error: 50
# 	 calPoint(value=33.10683275516641, error=59.27567472175075, timestamp=datetime.datetime(2021, 8, 30, 4, 15, 19))
# Suspicious LGM Temperature data ;	Reasonable data bounds: [3, 50] 	Reasonable Error: 50
# 	 calPoint(value=20.0, error=107.05946094686846, timestamp=datetime.datetime(2021, 7, 21, 4, 19, 21))
# 	 calPoint(value=20.0, error=186.6120994941537, timestamp=datetime.datetime(2021, 8, 23, 7, 58, 55))
# 	 calPoint(value=20.0, error=194.29467184212268, timestamp=datetime.datetime(2021, 8, 27, 7, 18, 11))
# 	 calPoint(value=20.0, error=191.12038077983243, timestamp=datetime.datetime(2021, 8, 30, 4, 18, 6))
# 	 calPoint(value=20.0, error=188.7592502489327, timestamp=datetime.datetime(2021, 8, 31, 4, 22, 26))
# 	 calPoint(value=20.0, error=192.657986320881, timestamp=datetime.datetime(2021, 9, 13, 4, 27, 55))
# 	 calPoint(value=20.0, error=194.41106998653666, timestamp=datetime.datetime(2021, 9, 21, 8, 18, 24))
# 	 calPoint(value=1.8122311158608625e-05, error=0.0005666518034218183, timestamp=datetime.datetime(2021, 9, 22, 4, 16, 46))
# 	 calPoint(value=20.0, error=191.87575665213103, timestamp=datetime.datetime(2021, 10, 12, 4, 11, 23))
# 	 calPoint(value=20.0, error=190.06245207390504, timestamp=datetime.datetime(2021, 10, 13, 4, 11, 24))
# 	 calPoint(value=20.0, error=191.80165449032845, timestamp=datetime.datetime(2021, 10, 21, 4, 21, 50))
# Suspicious Atom Loading Rate ;	Reasonable data bounds: [0.3, 0.95] 	Reasonable Error: 0.1
# 	 calPoint(value=0.8542857142857143, error=0.348828944689315, timestamp=datetime.datetime(2021, 8, 17, 4, 2))
# 	 calPoint(value=0.6928571428571428, error=0.43991766391042786, timestamp=datetime.datetime(2021, 8, 30, 4, 2, 14))
# 	 calPoint(value=0.3871428571428571, error=0.388861498873471, timestamp=datetime.datetime(2021, 9, 13, 4, 3, 55))
# 	 calPoint(value=0.10952380952380951, error=0.025661321114871388, timestamp=datetime.datetime(2021, 9, 21, 8, 9, 10))
# Suspicious Imaging Survival Data ;	Reasonable data bounds: [0, 1] 	Reasonable Error: 0.1
# 	 calPoint(value=0.14285714285714285, error=array([0.20369526, 0.49772746]), timestamp=datetime.datetime(2021, 7, 21, 4, 5, 12))
# Suspicious Atom Lifetime ;	Reasonable data bounds: [1000, 10000] 	Reasonable Error: inf
# 	 calPoint(value=-135.2269468905276, error=2094.589249711781, timestamp=datetime.datetime(2021, 8, 23, 9, 56, 12))
# 	 calPoint(value=192998.699519417, error=1194194.7167998047, timestamp=datetime.datetime(2021, 8, 30, 5, 29, 5))
# Suspicious Axial Trap Frequency ;	Reasonable data bounds: [20, 45] 	Reasonable Error: 5
# 	 calPoint(value=10.691680277208821, error=2.2508748138199817, timestamp=datetime.datetime(2021, 8, 23, 8, 25, 33))
# 	 calPoint(value=41.50640083430676, error=22.698716405380377, timestamp=datetime.datetime(2021, 8, 27, 7, 39, 8))
# 	 calPoint(value=41.00967154014404, error=437.0319912824382, timestamp=datetime.datetime(2021, 8, 30, 4, 39, 3))
# 	 calPoint(value=39.896592527558546, error=17.26420313872181, timestamp=datetime.datetime(2021, 9, 22, 4, 43, 31))
# Suspicious Radial+Axial Spot Size Value ;	Reasonable data bounds: [8e-07, 1.1e-06] 	Reasonable Error: inf
# 	 calPoint(value=2.46398759433034e-06, error=0, timestamp=datetime.datetime(2021, 8, 23, 8, 56, 29))
# 	 calPoint(value=6.881816347476692e-07, error=0, timestamp=datetime.datetime(2021, 8, 27, 8, 1, 14))
# 	 calPoint(value=6.903330163953773e-07, error=0, timestamp=datetime.datetime(2021, 8, 30, 5, 1, 9))
# 	 calPoint(value=1.1275835202008272e-06, error=0, timestamp=datetime.datetime(2021, 9, 21, 9, 16, 9))
# 	 calPoint(value=7.332782952445317e-07, error=0, timestamp=datetime.datetime(2021, 9, 22, 5, 14, 25))
# 	 calPoint(value=1.1526576659280123e-06, error=0, timestamp=datetime.datetime(2021, 10, 12, 5, 9, 18))
# 	 calPoint(value=1.2304713365413545e-06, error=0, timestamp=datetime.datetime(2021, 10, 21, 5, 19, 28))
# Suspicious Radial+Depth Spot Size Value ;	Reasonable data bounds: [6e-07, 9e-07] 	Reasonable Error: inf
# 	 calPoint(value=4.741604966030869e-07, error=12.029584481857114, timestamp=datetime.datetime(2021, 8, 30, 5, 13, 34))
# Suspicious Axial+Depth Spot Size Value ;	Reasonable data bounds: [7e-07, 1e-06] 	Reasonable Error: inf
# 	 calPoint(value=1.3343011013950032e-06, error=0, timestamp=datetime.datetime(2021, 8, 23, 9, 35, 6))
# 	 calPoint(value=6.815430176922435e-07, error=0, timestamp=datetime.datetime(2021, 8, 27, 8, 13, 37))
# 	 calPoint(value=5.721264247310546e-07, error=0, timestamp=datetime.datetime(2021, 8, 30, 5, 13, 34))
# 	 calPoint(value=6.940039782505329e-07, error=0, timestamp=datetime.datetime(2021, 9, 22, 5, 31, 12))
# Suspicious Radial+Axial Spot Size Value ;	Reasonable data bounds: [1, None] 	Reasonable Error: inf
# 	 calPoint(value=0.24820200960233016, error=1.3893833391058512, timestamp=datetime.datetime(2021, 8, 27, 7, 23, 15))
# 	 calPoint(value=3.5515564379437796e-06, error=2.3059428486956497, timestamp=datetime.datetime(2021, 8, 30, 4, 23, 10))
# Suspicious Axial Nbar ;	Reasonable data bounds: [0, 1] 	Reasonable Error: inf
# 	 calPoint(value=1.2775759173050587, error=2.3286933488345496, timestamp=datetime.datetime(2021, 8, 23, 8, 25, 33))
# 	 calPoint(value=1.6532006511488588, error=24.224147759053007, timestamp=datetime.datetime(2021, 8, 27, 7, 39, 8))
# 	 calPoint(value=6.955776167912778, error=2082.7419501176796, timestamp=datetime.datetime(2021, 8, 30, 4, 39, 3))
# Suspicious Radial Nbar ;	Reasonable data bounds: [0, 1] 	Reasonable Error: inf
# 	 calPoint(value=inf, error=6.745283763924183, timestamp=datetime.datetime(2021, 8, 30, 5, 1, 9))

# %% [markdown]
# # Today's Work

# %%
reloadMyModules(7)

# %%
atomlocs = [2, 2, 3, 7, 1]

# %%
mp.Loading(18,atomlocs);
# Out:
# ### File 18 (7x1_Atom_Loading_And_Imaging_RPGC): loading depth
# Number of Pictures: 400; Picture Dimensions: 5 x 23
# Variations: 8;	Repetitions: 25;	Exp File Version: 4;
# Experiment started at (H:M:S) 10:22:29: on (Y-M-D) 2022-11-7, And ended at 10:25:5: on 2022-11-7
# Experiment Notes: image detuning at -1.8

# %%
mp.Loading(21,atomlocs,tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 100)]);
# Out:
# ### File 21 (7x1_Atom_Loading_And_Imaging_RPGC): side mot imaging power
# Number of Pictures: 400; Picture Dimensions: 5 x 23
# Variations: 8;	Repetitions: 25;	Exp File Version: 4;
# Experiment started at (H:M:S) 10:41:20: on (Y-M-D) 2022-11-7, And ended at 10:43:42: on 2022-11-7
# Experiment Notes: needs to be pretty high
