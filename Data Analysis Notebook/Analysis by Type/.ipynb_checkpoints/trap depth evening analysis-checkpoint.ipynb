# %% [markdown]
# # July 27, 2021 (Tuesday) Data Analysis Notebook

# %%
# current date, for retrieving data from proper location.
year = "2021"
month = "July"
day = "27"

# %% [markdown]
# ## Imports and initialization

# %%
from matplotlib import gridspec

# %%
import scipy.signal

# %%
# %config Completer.use_jedi = False
import numpy as np 
from numpy import array as arr
import pandas as pd
import plotly.offline as pltly
pltly.init_notebook_mode(connected=True)
from plotly import graph_objs as go
import math
import scipy.optimize as opt
from scipy import ndimage
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap
import warnings 
warnings.filterwarnings('module')
from datetime import datetime
import uncertainties.unumpy
import IPython
import pandas as pd
import pickle

from matplotlib.pyplot import *
from matplotlib import rcParams
from matplotlib import style
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# ## set matplotlib plot defaults :D
# Style controls many default colors in matplotlib plots.
# Change the following if you don't like dark backgrounds. Many other options.
import matplotlib as mpl

if False:
    # My Dark Settings
    style.use(['dark_background'])
    c = '#0A0A0A'
    mpl.rcParams['axes.facecolor'] = '#000000'
    mpl.rcParams['figure.edgecolor'] = c
    mpl.rcParams['figure.facecolor'] = c
else:
    # My Light Settings
    style.use(['default'])
    c = '#FFFFFF'
    mpl.rcParams['axes.facecolor'] = c
    mpl.rcParams['figure.edgecolor'] = c
    mpl.rcParams['figure.facecolor'] = c  
# the default cycling of colors in this mode isn't very good.
#rcParams['axes.prop_cycle'] = ("cycler('color', ['r','c','g','#FFFFFF','b']) + cycler('marker', ['o','v','<','>','^'])")
### General
mpl.rcParams['figure.figsize'] = (25.0, 8.0)
mpl.rcParams['axes.grid'] = True
mpl.rcParams['axes.formatter.useoffset'] = False
mpl.rcParams['grid.alpha'] = 0.15
mpl.rcParams['axes.formatter.limits'] = (-3,3)
mpl.rcParams['image.cmap'] = 'viridis'
#rcParams['image.cmap'] = dark_viridis_cmap
# to see all available options, decomment this line.
# print(mpl.rcParams)
mpl.rcParams['font.size'] = 14
viridis = cm.get_cmap('viridis', 256)
dark_viridis = []
bl = 0.15
for i in range(256):
    dark_viridis.append(list(viridis(i)))
    dark_viridis[-1][0] = dark_viridis[-1][0] *(bl+(1-bl)*i/255)
    dark_viridis[-1][1] = dark_viridis[-1][1] *(bl+(1-bl)*i/255)
    dark_viridis[-1][2] = dark_viridis[-1][2] *(bl+(1-bl)*i/255)
dark_viridis_cmap = ListedColormap(dark_viridis)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import mpl_toolkits.axes_grid1
import matplotlib.gridspec as gridspec
from skimage.transform import iradon
# Out:
# //anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# //anaconda3/lib/python3.7/site-packages/pywt/_utils.py:6: DeprecationWarning:
#
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working

# %%
dark_viridis_cmap

# %%
import sys
sys.path.append("..")
from Analysis_Python_Files.fitters.Gaussian import dip, double_dip, bump, bump2, bump3, bump2r, gaussian, bump3_Sym, gaussian_2d
from Analysis_Python_Files.fitters.Sinc_Squared import sinc_sq3_Sym, sinc_sq
from Analysis_Python_Files.fitters import decaying_cos, exponential_decay_fixed_limit as decay, linear, LargeBeamMotExpansion, n1State
import Analysis_Python_Files.PictureWindow as pw
import Analysis_Python_Files.ExpFile as exp
exp.setPath(day, month, year)
import Analysis_Python_Files.PlotlyPlotters as pp
import Analysis_Python_Files.MatplotlibPlotters as mp
import Analysis_Python_Files.MainAnalysis as ma
import Analysis_Python_Files.AnalysisHelpers as ah
import Analysis_Python_Files.Miscellaneous as misc
import Analysis_Python_Files.PopulationAnalysis as pa
import Analysis_Python_Files.MarksConstants as mc
import Analysis_Python_Files.fitters as fitters
import Analysis_Python_Files.LoadingFunctions as lf
import Analysis_Python_Files.FreeSpaceImaging as fsi
import Analysis_Python_Files.TransferAnalysis as ta
import Analysis_Python_Files.LightShiftCalculations as lsc
import Analysis_Python_Files.CalibrationAnalysis as ca
# It's important to explicitly import calPoint here or else pickling doesn't work.
from Analysis_Python_Files.CalibrationAnalysis import calPoint 
from Analysis_Python_Files.TransferAnalysisOptions import TransferAnalysisOptions as ao
import Analysis_Python_Files.ThresholdOptions as to
import Analysis_Python_Files.TransferAnalysisOptions as tao

# %% [markdown]
# import imp
# def reloadAll(day_=None, diplsayErrors=False):
#     for module in sys.modules.values():
#         try:
#             reload(module)
#         except NotImplementedError:
#             if diplsayErrors:
#                 print(module, 'NotImplementedError')
#         except AttributeError:
#             if diplsayErrors:
#                 print(module, 'AttributeError')
#         except TypeError:
#             if diplsayErrors:
#                 print(module, 'ValueError')
#         except ImportError:
#             if diplsayErrors:
#                 print(module, 'ImportError')
#     if day_ is None:
#         day_ = day
#     setPath(day_,month,year)

# %%
from importlib import reload
def reloadMyModules(day_=None, month_=None, year_=None):
    reload(exp)
    if day_ is None:
        day_ = day
    if month_ is None:
        month_ = month
    if year_ is None:
        year_ = year
    exp.setPath(day_,month_,year_,sl="/")
    reload(lf)
    reload(misc)
    reload(ma)
    reload(ah)
    reload(pp)
    reload(mp)
    reload(fitters)
    reload(fsi)
    reload(ta)
    reload(pa)
    reload(tao)
    reload(to)
    reload(ca)
reloadMyModules()

# %% [markdown]
# ## Standard Calibrations

# %% [markdown]
# ### Temperature

# %% [markdown]
# #### Running Temperature

# %%
reload(ca)
cTemps, cTimes = ca.loadAllTemperatureData()
legends = ['1: Master Computer', '2: B236', '3: Auxiliary Table', '4: Main Exp. (Near Ion Pump)']
fig, ax = plt.subplots(figsize=(20,10))
for temp,lab in zip(misc.transpose(cTemps), legends):
    ax.plot(cTimes,temp, label=lab, alpha=0.5, linewidth=1)
ax.legend()
ax.set_title('Lab Temperature Record');
ax.set_ylim(20,30)

# %%
fig, ax = plt.subplots()
for temp,lab in zip(misc.transpose(cTemps), legends):
    ax.plot(cTimes[-50000:],temp[-50000:], label=lab, alpha=0.5, linewidth=1)

# %% [markdown]
# #### Today's Temperature

# %%
reloadMyModules()
ah.Temperature();

# %% [markdown]
# ## individual calibrations

# %%
sCalData = ca.std_analyzeAll()

# %%
with open(exp.dataAddress + 'CalibrationData.p','wb') as calFile:
    pickle.dump(sCalData, calFile)

# %% [markdown]
# ## Calibration Summmary

# %%
# load all past calibration data into a bigger strucutre.
reloadMyModules()
calData = ca.loadAllCalData()
reloadMyModules(day_=day)

# %%
reload(ca)
ca.checkData(calData)

# %% [markdown]
# # Today's Work

# %%
reloadMyModules(27)

# %% [markdown]
# ### Optimizing Imaging

# %% [markdown]
# #### Scan of the image_detuning

# %%
atomlocs = [2, 2, 3, 7, 1]

# %%
mp.Loading(1,atomlocs,usePickle=False,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
# Out:
# ### File 1 (7x1_Atom_Loading_And_Imaging): dl loading freq
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_1.h5
# open successfully <HDF5 file "data_1.h5" (mode r)>
# Number of Pictures: 4100; Picture Dimensions: 5 x 23
# Variations: 41;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 14:58:24: on (Y-M-D) 2021-7-27, And ended at 15:14:1: on 2021-7-27
# Experiment Notes: need to use manual threshold

# %%
mp.Loading(2,atomlocs,usePickle=False,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
# Out:
# ### File 2 (7x1_Atom_Loading_And_Imaging): dl loading depth
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_2.h5
# open successfully <HDF5 file "data_2.h5" (mode r)>
# Number of Pictures: 4000; Picture Dimensions: 5 x 23
# Variations: 20;	Repetitions: 100;	Exp File Version: 4;
# Experiment started at (H:M:S) 15:31:33: on (Y-M-D) 2021-7-27, And ended at 15:46:5: on 2021-7-27
# Experiment Notes: small peaks from previous plot are gone. There must be something that needs to be fixed

# %%
mp.Loading(3,atomlocs,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
# Out:
# ### File 3 (7x1_Atom_Loading_And_Imaging): dl loading freq for 85 transition
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_3.h5
# open successfully <HDF5 file "data_3.h5" (mode r)>
# Number of Pictures: 4000; Picture Dimensions: 5 x 23
# Variations: 20;	Repetitions: 100;	Exp File Version: 4;
# Experiment started at (H:M:S) 15:52:23: on (Y-M-D) 2021-7-27, And ended at 16:6:55: on 2021-7-27
# Experiment Notes: laser is locked but still no survival

# %%
mp.Loading(4,atomlocs,usePickle=False,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
# Out:
# ### File 4 (7x1_Atom_Loading_And_Imaging): dl loading freq - d1 F'=1
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_4.h5
# open successfully <HDF5 file "data_4.h5" (mode r)>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-44ffc83392a6> in <module>
# ----> 1 mp.Loading(4,atomlocs,usePickle=False,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
#
# ~/Data-Analysis-Code/Analysis_Python_Files/MatplotlibPlotters.py in Loading(fileID, atomLocs, **TransferArgs)
#     994     A small wrapper, partially for the extra defaults in this case partially for consistency with old function definitions.
#     995     """
# --> 996     return Transfer(fileID, tao.getStandardLoadingOptions(atomLocs), atomLocs, **TransferArgs)
#     997
#     998 def Population(fileNum, atomLocations, whichPic, picsPerRep, plotLoadingRate=True, legendOption=None, showImagePlots=True,
#
# ~/Data-Analysis-Code/Analysis_Python_Files/MatplotlibPlotters.py in Transfer(fileNumber, analysisOpts, show, legendOption, fitModules, showFitDetails, showFitCharacterPlot, showImagePlots, plotIndvHists, timeit, outputThresholds, plotFitGuess, newAnnotation, plotImagingSignal, expFile_version, plotAvg, countMain, histMain, flattenKeyDim, forceNoAnnotation, cleanOutput, dataColor, dataEdgeColors, tOptions, resInput, countRunningAvg, useBase, usePickle, **standardTransferArgs)
#     957         disp.clear_output()
#     958     disp.display(disp.Markdown(expTitle))
# --> 959     with exp.ExpFile(fileNumber,expFile_version=expFile_version, useBase=useBase) as fid:
#     960         fid.get_basic_info()
#     961
#
# ~/Data-Analysis-Code/Analysis_Python_Files/ExpFile.py in __init__(self, file_id, expFile_version, useBase, keyParameter)
#     174             else:
#     175                 self.key_name, self.key = self.get_key(keyParameter=keyParameter)
# --> 176             self.pics = self.get_pics()
#     177             self.reps = self.get_reps()
#     178             self.exp_start_date, self.exp_start_time, self.exp_stop_date, self.exp_stop_time = self.get_experiment_time_and_date()
#
# ~/Data-Analysis-Code/Analysis_Python_Files/ExpFile.py in get_pics(self)
#     277
#     278     def get_pics(self):
# --> 279         p_t = arr(self.f['Andor']['Pictures'])
#     280         pics = p_t.reshape((p_t.shape[0], p_t.shape[2], p_t.shape[1]))
#     281         return pics
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# //anaconda3/lib/python3.7/site-packages/h5py/_hl/group.py in __getitem__(self, name)
#     260                 raise ValueError("Invalid HDF5 object reference")
#     261         else:
# --> 262             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     263
#     264         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5o.pyx in h5py.h5o.open()
#
# KeyError: "Unable to open object (file read failed: time = Tue Jul 27 16:29:22 2021\n, filename = '/Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_4.h5', file descriptor = 79, errno = 6, error message = 'Device not configured', buf = 0x7fd4d5a1c2f0, total read size = 512, bytes this sub-read = 512, bytes actually read = 18446744073709551615, offset = 359696)"

# %%
mp.Loading(8,atomlocs,usePickle=False,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
# Out:
# ### File 8 (7x1_Atom_Loading_And_Imaging): Side mot Power
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_8.h5
# open successfully <HDF5 file "data_8.h5" (mode r)>
# Number of Pictures: 800; Picture Dimensions: 5 x 23
# Variations: 8;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:58:12: on (Y-M-D) 2021-7-27, And ended at 17:1:18: on 2021-7-27
# Experiment Notes: looks good, let's go from 1.4-2

# %%
mp.Loading(7,atomlocs,usePickle=False,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
# Out:
# ### File 7 (7x1_Atom_Loading_And_Imaging): Loading depth - d1 F'=1
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_7.h5
# open successfully <HDF5 file "data_7.h5" (mode r)>
# Number of Pictures: 900; Picture Dimensions: 5 x 23
# Variations: 9;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:50:11: on (Y-M-D) 2021-7-27, And ended at 16:53:58: on 2021-7-27
# Experiment Notes: same as previous transition

# %%
mp.Loading(9,atomlocs,usePickle=False,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
# Out:
# ### File 9 (7x1_Atom_Loading_And_Imaging): side mot power - higher scan
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_9.h5
# open successfully <HDF5 file "data_9.h5" (mode r)>
# Number of Pictures: 800; Picture Dimensions: 5 x 23
# Variations: 8;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 17:4:53: on (Y-M-D) 2021-7-27, And ended at 17:7:59: on 2021-7-27
# Experiment Notes: improves a little bit at high powers

# %%
mp.Loading(10,atomlocs,usePickle=False,tOptions=[to.ThresholdOptions(manualThreshold=True,manualThresholdValue=250)]);
# Out:
# ### File 10 (7x1_Atom_Loading_And_Imaging): diag mot power - d1 F'=1
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_10.h5
# open successfully <HDF5 file "data_10.h5" (mode r)>
# Number of Pictures: 800; Picture Dimensions: 5 x 23
# Variations: 8;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 17:12:5: on (Y-M-D) 2021-7-27, And ended at 17:15:10: on 2021-7-27
# Experiment Notes: peak at .3 as expected

# %%
tares = ta.standardTransferAnalysis(11, tao.getStandardLoadingOptions([2,2,3,7,1]));
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key, repetitions, initThresholds, 
            fits, avgTferData, avgTferErr, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated) = tares
key1 = list(sorted(set(key[:,0])))
key2 = list(sorted(set(key[:,1])))
datam = np.zeros((len(key2),len(key1)))
errsm = np.zeros((len(key2),len(key1),2))
for kv, dp, errs in zip(key, avgTferData, avgTferErr):
    i1 = key1.index(kv[0])
    i2 = key2.index(kv[1])
    datam[i2,i1] = dp
    errsm[i2,i1] = errs
k1sp = np.array(key1[1])-np.array(key1[0])
key1Pl = np.append(key1 - k1sp/2, [key1[-1]+k1sp])
k2sp = np.array(key2[1])-np.array(key2[0])
key2Pl = np.append(key2 - k2sp/2, [key2[-1]+k2sp])
# 
fig, ax = plt.subplots(figsize=(12,7))
#plt.pcolormesh(key1Pl, key2Pl, datam_ram, vmin=0, vmax=0.85)
im=ax.pcolormesh(935-key1Pl*8, key2Pl/21, datam, vmin=0)
ax.set_xlabel('Approx LGM Detuning (zero set by hand) (MHz)')
ax.set_ylabel('Trap Depth (mK)')
ax.invert_yaxis()
cb, cax = mp.addAxColorbar(fig,ax,im)
cax.set_title('Loading Fraction')
# Out:
# sta: Organizing Transfer Data...
# hdf5 /Volumes/Local_Data_Repository/2021/July/July 27/Raw Data/data_11.h5
# open successfully <HDF5 file "data_11.h5" (mode r)>
# Number of Pictures: 48000; Picture Dimensions: 5 x 23
# Variations: 240;	Repetitions: 100;	Exp File Version: 4;
# Experiment started at (H:M:S) 17:37:34: on (Y-M-D) 2021-7-27, And ended at 20:36:37: on 2021-7-27
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# sta: Getting Transfer Thresholds...
# //anaconda3/lib/python3.7/site-packages/scipy/optimize/minpack.py:799: OptimizeWarning:
#
# Covariance of the parameters could not be estimated
# sta: Determining Atom Prescence...
# sta: Getting Transfer Atom Images...
# sta: Post-Selecting...................................................................................................................................................................................................................................................sta: Getting Transfer Averages...
# sta: Getting Load Averages...
# sta: Handling Fitting...
# [111.0, 112.05263157894737, 113.10526315789474, 114.15789473684211, 115.21052631578948, 116.26315789473685, 117.3157894736842, 118.36842105263158, 119.42105263157895, 120.47368421052632, 121.52631578947368, 122.57894736842105, 123.63157894736842, 124.6842105263158, 125.73684210526315, 126.78947368421052, 127.84210526315789, 128.89473684210526, 129.94736842105263, 131.0]
# Text(0.5, 1.0, 'Loading Fraction')

# %%
import h5py as h5
filename = "data_1.h5"

with h5py.File(filename, "r") as f:
    # List all groups
    print("Keys: %s" % f.keys())
    a_group_key = list(f.keys())[0]

    # Get the data
    data = list(f[a_group_key])
# Out:
# Keys: <KeysViewHDF5 ['AI:NA', 'Agilents', 'Andor', 'AndorAlignment', 'Ao_System', 'Basler', 'Do_System', 'Master-Input', 'Master-Runtime', 'Microwave', 'Miscellaneous', 'NIAWG', 'TTLs']>

# %%
print()
