# %%
# current date, for retrieving data from proper location.
year = "2023"
day ="29"
month = "september"

# %% [markdown]
# ## Imports and initialization

# %%
from matplotlib import gridspec
import scipy.signal
# %config Completer.use_jedi = False
import numpy as np 
from numpy import array as arr
import pandas as pd
import plotly.offline as pltly
pltly.init_notebook_mode(connected=True)
from plotly import graph_objs as go
import math
import scipy.optimize as opt
from scipy import ndimage
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap
import warnings 
warnings.filterwarnings('module')
from datetime import datetime
import uncertainties.unumpy
import IPython
import pandas as pd
import pickle
from matplotlib.ticker import ScalarFormatter
from matplotlib.pyplot import *
from matplotlib import rcParams
from matplotlib import style
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
# %matplotlib inline

# ## set matplotlib plot defaults :D
# Style controls many default colors in matplotlib plots.
# Change the following if you don't like dark backgrounds. Many other options.
import matplotlib as mpl

if False:
    # My Dark Settings
    style.use(['dark_background'])
    c = '#0A0A0A'
    mpl.rcParams['axes.facecolor'] = '#000000'
    mpl.rcParams['figure.edgecolor'] = c
    mpl.rcParams['figure.facecolor'] = c
else:
    # My Light Settings
    style.use(['default'])
    c = '#FFFFFF'
    mpl.rcParams['axes.facecolor'] = c
    mpl.rcParams['figure.edgecolor'] = c
    mpl.rcParams['figure.facecolor'] = c  
# the default cycling of colors in this mode isn't very good.
#rcParams['axes.prop_cycle'] = ("cycler('color', ['r','c','g','#FFFFFF','b']) + cycler('marker', ['o','v','<','>','^'])")
### General
mpl.rcParams['figure.figsize'] = (25.0, 8.0)
mpl.rcParams['axes.grid'] = True
mpl.rcParams['axes.formatter.useoffset'] = False
mpl.rcParams['grid.alpha'] = 0.15
mpl.rcParams['axes.formatter.limits'] = (-3,3)
mpl.rcParams['image.cmap'] = 'viridis'
#rcParams['image.cmap'] = dark_viridis_cmap
# to see all available options, decomment this line.
# print(mpl.rcParams)
mpl.rcParams['font.size'] = 14
viridis = cm.get_cmap('viridis', 256)
dark_viridis = []
bl = 0.15
for i in range(256):
    dark_viridis.append(list(viridis(i)))
    dark_viridis[-1][0] = dark_viridis[-1][0] *(bl+(1-bl)*i/255)
    dark_viridis[-1][1] = dark_viridis[-1][1] *(bl+(1-bl)*i/255)
    dark_viridis[-1][2] = dark_viridis[-1][2] *(bl+(1-bl)*i/255)
dark_viridis_cmap = ListedColormap(dark_viridis)
import mpl_toolkits.axes_grid1
import matplotlib.gridspec as gridspec
from skimage.transform import iradon
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import sys
sys.path.append("..")
from Analysis_Python_Files.fitters.Gaussian import dip, double_dip,arb_1d_sum, bump, bump2, bump3, bump2r, gaussian, bump3_Sym, gaussian_2d, poly_nom
from Analysis_Python_Files.fitters.Sinc_Squared import sinc_sq3_Sym, sinc_sq
from Analysis_Python_Files.fitters import decaying_cos, exponential_decay_fixed_limit as decay, linear, LargeBeamMotExpansion, n1State
import Analysis_Python_Files.PictureWindow as pw
import Analysis_Python_Files.ExpFile as exp
# import Analysis_Python_Files.UnitConversion as uc
exp.setPath(day, month, year)
import Analysis_Python_Files.PlotlyPlotters as pp
import Analysis_Python_Files.MatplotlibPlotters as mp
import Analysis_Python_Files.MatplotlibPlotters_pres as mp_pres
import Analysis_Python_Files.MainAnalysis as ma
import Analysis_Python_Files.AnalysisHelpers as ah
import Analysis_Python_Files.Miscellaneous as misc
import Analysis_Python_Files.PopulationAnalysis as pa
import Analysis_Python_Files.MarksConstants as mc
import Analysis_Python_Files.fitters as fitters
import Analysis_Python_Files.LoadingFunctions as lf
import Analysis_Python_Files.FreeSpaceImaging as fsi
import Analysis_Python_Files.TransferAnalysis as ta
import Analysis_Python_Files.LightShiftCalculations as lsc
import Analysis_Python_Files.CalibrationAnalysis as ca
# It's important to explicitly import calPoint here or else pickling doesn't work.
from Analysis_Python_Files.CalibrationAnalysis import calPoint 
from Analysis_Python_Files.TransferAnalysisOptions import TransferAnalysisOptions as ao
import Analysis_Python_Files.ThresholdOptions as to
import Analysis_Python_Files.TransferAnalysisOptions as tao
from importlib import reload
def reloadMyModules(day_=None, month_=None, year_=None):
    reload(exp)
    if day_ is None:
        day_ = day
    if month_ is None:
        month_ = month
    if year_ is None:
        year_ = year
    exp.setPath(day_,month_,year_)
    reload(lf)
    reload(misc)
    reload(ma)
    reload(ah)
    reload(pp)
    reload(mp)
    reload(fitters)
    reload(fsi)
    reload(ta)
    reload(pa)
    reload(tao)
    reload(to)
    reload(ca)
reloadMyModules()

# %%
atomlocs = [2, 2, 3, 3, 1]

# %%
loadNone = tao.condition([0,0,0], [0,1,2], [0,0,0])

loadOne = tao.condition([0,0,0], [0,1,2], [1,1,1], numRequired = 1, name = 'Load any one tweezer')
# tao.condition([0 = 1st pic, 1 = 2nd pic],

loadTwo = tao.condition([0,0,0], [0,1,2], [1,1,1], numRequired = 2, name = 'Load any two tweezers')
loadThree = tao.condition([0,0,0], [0,1,2], [1,1,1], numRequired = 3, name = 'Load all three tweezers')
loadOuter = tao.condition([0,0,0], [0,1,2], [1,0,1], numRequired = 2, name = 'Load outer tweezers')

finCenter = tao.condition([1],[1],[1], markerWhichPicList=[1], markerLocList=[1])
# 
# loadOpt= tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadOne], [loadTwo], [loadThree]],[finCenter for _ in range(3)]);
loadOpt= tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadOne], [loadTwo]],[finCenter for _ in range(2)]);
loadOneOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadOne]],[finCenter for _ in range(1)]);
loadTwoOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadTwo]],[finCenter for _ in range(1)]);
loadThreeOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadThree]],[finCenter for _ in range(1)]);
loadOuterOpt = tao.TransferAnalysisOptions(atomlocs, atomlocs, 0,1, [[loadOuter]],[finCenter for _ in range(1)]);

# %%
def decay_exponential(x, A, k, C):
    return A * np.exp(-k * x) + C

# %%
reloadMyModules(10,'October')
mp.Transfer(20, loadOpt, plotIndvHists = True, plotAvg=False, 
            tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = 80)]);
# Out:
# ### File 20 (2_0_rate_measurement):
# Number of Pictures: 800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 14:24:31: on (Y-M-D) 2023-10-10, And ended at 14:27:52: on 2023-10-10
# Experiment Notes:

# %% [markdown]
# # D1 F=2-1' Red

# %% [markdown]
# ## -400 MHz (DDS=181.34)

# %%
##pulse duration
reloadMyModules(29,'september')
fileId = 25
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -400 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r400_F21 = decay_constant
gamma_r400_unc_F21 = decay_constant_uncertainty
tau_r400_F21 = one_over_e_time
tau_r400_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 15:48:51: on (Y-M-D) 2023-9-29, And ended at 16:11:41: on 2023-9-29
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.011856626025541302 gamma uncertainty = 0.002681024033711567

# %% [markdown]
# ## -300 MHz (DDS=168.34)

# %%
##pulse duration
reloadMyModules(29,'september')
fileId = 24
threshold = 90
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -300 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r300_F21 = decay_constant
gamma_r300_unc_F21 = decay_constant_uncertainty
tau_r300_F21 = one_over_e_time
tau_r300_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 15:22:39: on (Y-M-D) 2023-9-29, And ended at 15:45:29: on 2023-9-29
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.015011949699217696 gamma uncertainty = 0.002735190031325297

# %% [markdown]
# ## -250 MHz (DDS=162.59)

# %%
##pulse duration
reloadMyModules(29,'september')
fileId = 26
threshold = 75
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -250 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r250_F21 = decay_constant*1.5
gamma_r250_unc_F21 = decay_constant_uncertainty
tau_r250_F21 = one_over_e_time
tau_r250_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:17:53: on (Y-M-D) 2023-9-29, And ended at 16:42:44: on 2023-9-29
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.018203855497076305 gamma uncertainty = 0.00850880272845762

# %% [markdown]
# ## -200 MHz (DDS=156.34)

# %%
##pulse duration
reloadMyModules(29,'september')
fileId = 27
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
# avgTferData1[4] = 0.3
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -200 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r200_F21 = decay_constant
gamma_r200_unc_F21 = decay_constant_uncertainty
tau_r200_F21 = one_over_e_time
tau_r200_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:47:56: on (Y-M-D) 2023-9-29, And ended at 17:8:46: on 2023-9-29
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.038285430916761586 gamma uncertainty = 0.009756377193113524

# %% [markdown]
# ## -150 MHz (DDS=-150.09)

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 18
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -150 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r150_F21 = decay_constant
gamma_r150_unc_F21 = decay_constant_uncertainty
tau_r150_F21 = one_over_e_time
tau_r150_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 21:40:38: on (Y-M-D) 2023-10-3, And ended at 22:3:24: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.02612553045523835 gamma uncertainty = 0.00481023803634208

# %% [markdown]
# ## -100 MHz (DDS=143.84)

# %%
##pulse duration
reloadMyModules(29,'september')
fileId = 31
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -100 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r100_F21 = decay_constant
gamma_r100_unc_F21 = decay_constant_uncertainty
tau_r100_F21 = one_over_e_time
tau_r100_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 19:37:21: on (Y-M-D) 2023-9-29, And ended at 20:0:10: on 2023-9-29
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.01301253045728211 gamma uncertainty = 0.004232837144934938

# %% [markdown]
# ## -50 MHz (DDS=137.59)

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 17
threshold = 90
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -50 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r50_F21 = decay_constant
gamma_r50_unc_F21 = decay_constant_uncertainty
tau_r50_F21 = one_over_e_time
tau_r50_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 21:0:49: on (Y-M-D) 2023-10-3, And ended at 21:23:35: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.009674697630632447 gamma uncertainty = 0.0022451096104185463

# %% [markdown]
# # D1 F=2-2' blue

# %% [markdown]
# ## 400 MHz (DDS=66.68)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 24
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +400 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b400_F22 = decay_constant
gamma_b400_unc_F22 = decay_constant_uncertainty
tau_b400_F22 = one_over_e_time
tau_b400_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:57:10: on (Y-M-D) 2023-10-2, And ended at 17:20:2: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.014656194984972889 gamma uncertainty = 0.006042673480232051

# %% [markdown]
# ## 300 MHz (DDS=79.18)

# %%
##pulse duration
reloadMyModules(2,"October")
fileId = 23
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +300 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain')

gamma_b300_F22 = decay_constant
gamma_b300_unc_F22 = decay_constant_uncertainty
tau_b300_F22 = one_over_e_time
tau_b300_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:32:49: on (Y-M-D) 2023-10-2, And ended at 16:55:42: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.02488448385520342 gamma uncertainty = 0.005087371512606676

# %% [markdown]
# ## 250 MHz (DDS=85.43)

# %%
##pulse duration
reloadMyModules(2,"October")
fileId = 22
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +250 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 

gamma_b250_F22 = decay_constant
gamma_b250_unc_F22 = decay_constant_uncertainty
tau_b250_F22 = one_over_e_time
tau_b250_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:5:14: on (Y-M-D) 2023-10-2, And ended at 16:26:8: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.030270934765887072 gamma uncertainty = 0.007117413921657659

# %% [markdown]
# ## 200 MHz (DDS=91.68)

# %%
##pulse duration
reloadMyModules(2,"October")
fileId = 21
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +200 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b200_F22 = decay_constant
gamma_b200_unc_F22 = decay_constant_uncertainty
tau_b200_F22 = one_over_e_time
tau_b200_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 14:51:39: on (Y-M-D) 2023-10-2, And ended at 15:12:32: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.031319904996200826 gamma uncertainty = 0.005465623579428064

# %% [markdown]
# ## 150 MHz (DDS=97.93)

# %%
##pulse duration
reloadMyModules(2,"October")
fileId = 8
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +150 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b150_F22 = decay_constant
gamma_b150_unc_F22 = decay_constant_uncertainty
tau_b150_F22 = one_over_e_time
tau_b150_unc_F22 = one_over_e_time_uncertainty
print('gamma=',decay_constant,'gamma uncertainty=',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 10:33:36: on (Y-M-D) 2023-10-2, And ended at 10:52:28: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma= 0.03855038117742626 gamma uncertainty= 0.007193821783551937

# %%
##pulse duration
reloadMyModules(10,"October")
fileId = 22
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +150 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 

# gamma_b150_F22 = decay_constant
# gamma_b150_unc_F22 = decay_constant_uncertainty
# tau_b150_F22 = one_over_e_time
# tau_b150_unc_F22 = one_over_e_time_uncertainty
# print('gamma=',decay_constant,'gamma uncertainty=',decay_constant_uncertainty)
# Out:
# Number of Pictures: 800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 14:34:0: on (Y-M-D) 2023-10-10, And ended at 14:37:21: on 2023-10-10
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.

# %% [markdown]
# ## 125 MHz (DDS=103.05)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 9
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +125 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b125_F22 = decay_constant
gamma_b125_unc_F22 = decay_constant_uncertainty
tau_b125_F22 = one_over_e_time
tau_b125_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 10:54:41: on (Y-M-D) 2023-10-2, And ended at 11:13:33: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.04379612127866909 gamma uncertainty = 0.009077610984480317

# %% [markdown]
# ## 100 MHz (DDS=104.18)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 7
threshold = 90
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)
gamma_b100_F22 = decay_constant
gamma_b100_unc_F22 = decay_constant_uncertainty
tau_b100_F22 = one_over_e_time
tau_b100_unc_F22 = one_over_e_time_uncertainty

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +100 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 10:13:9: on (Y-M-D) 2023-10-2, And ended at 10:32:0: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.05633810279389516 gamma uncertainty = 0.007757643975606576

# %% [markdown]
# ## 87.5 MHz (DDS=107.75)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 10
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +87.5 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b87_F22 = decay_constant
gamma_b87_unc_F22 = decay_constant_uncertainty
tau_b87_F22 = one_over_e_time
tau_b87_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 11:16:31: on (Y-M-D) 2023-10-2, And ended at 11:35:24: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.07067163861920162 gamma uncertainty = 0.02264324415569406

# %% [markdown]
# ## 75 MHz (DDS=107.3)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 11
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +75 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b75_F22 = decay_constant
gamma_b75_unc_F22 = decay_constant_uncertainty
tau_b75_F22 = one_over_e_time
tau_b75_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 11:37:16: on (Y-M-D) 2023-10-2, And ended at 11:55:9: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.08403200073104884 gamma uncertainty = 0.026411918931932454

# %% [markdown]
# ## 62.5 MHz (DDS=108.86)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 13
threshold = 90
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +62.5 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')

# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b62_F22 = decay_constant
gamma_b62_unc_F22 = decay_constant_uncertainty
tau_b62_F22 = one_over_e_time
tau_b62_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 12:22:14: on (Y-M-D) 2023-10-2, And ended at 12:41:6: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.058320935520740316 gamma uncertainty = 0.01575726437545893

# %% [markdown]
# ## 50 MHz (DDS=110.43)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 12
threshold = 90
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / (decay_constant ** 2)

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = +50 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b50_F22 = decay_constant
gamma_b50_unc_F22 = decay_constant_uncertainty
tau_b50_F22 = one_over_e_time
tau_b50_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 11:58:14: on (Y-M-D) 2023-10-2, And ended at 12:17:6: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.030035921378281056 gamma uncertainty = 0.008009569121451296

# %% [markdown]
# # D1 F=2-1' Blue

# %% [markdown]
# ## 50 MHz

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 8
threshold = 90
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -500 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b50_F21 = decay_constant
gamma_b50_unc_F21 = decay_constant_uncertainty
tau_b50_F21 = one_over_e_time
tau_b50_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 12:36:45: on (Y-M-D) 2023-10-3, And ended at 13:3:38: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.007062410317795689 gamma uncertainty = 0.002214162912771325
# /var/folders/p1/sslzk5t517d2pwp06md4xf_w0000gn/T/ipykernel_1495/604109091.py:2: RuntimeWarning:
#
# overflow encountered in exp

# %% [markdown]
# ## 100 MHz

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 11
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 100 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b100_F21 = decay_constant
gamma_b100_unc_F21 = decay_constant_uncertainty
tau_b100_F21 = one_over_e_time
tau_b100_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 14:31:55: on (Y-M-D) 2023-10-3, And ended at 14:58:48: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.013588105565189875 gamma uncertainty = 0.003975373432887854
# /var/folders/p1/sslzk5t517d2pwp06md4xf_w0000gn/T/ipykernel_1495/604109091.py:2: RuntimeWarning:
#
# overflow encountered in exp

# %% [markdown]
# ## 125 MHz ***

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 12
threshold = 100
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 125 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b125_unc_F21 = decay_constant
gamma_b125_unc_F21 = decay_constant_uncertainty/2
tau_b125_unc_F21 = one_over_e_time
tau_b125_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 15:5:2: on (Y-M-D) 2023-10-3, And ended at 15:31:55: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.025719750737020316 gamma uncertainty = 0.01015548192159559
# /var/folders/p1/sslzk5t517d2pwp06md4xf_w0000gn/T/ipykernel_1495/604109091.py:2: RuntimeWarning:
#
# overflow encountered in exp

# %% [markdown]
# ## 150 MHz

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 13
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 150 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b150_unc_F21 = decay_constant
gamma_b150_unc_F21 = decay_constant_uncertainty*3
tau_b150_unc_F21 = one_over_e_time
tau_b150_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 15:34:25: on (Y-M-D) 2023-10-3, And ended at 16:1:20: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.010885265461253688 gamma uncertainty = 0.0012958549434318003
# /var/folders/p1/sslzk5t517d2pwp06md4xf_w0000gn/T/ipykernel_1495/604109091.py:2: RuntimeWarning:
#
# overflow encountered in exp

# %% [markdown]
# ## 175 MHz

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 16
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [.8, 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 175 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-1} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_b175_unc_F21 = decay_constant
gamma_b175_unc_F21 = decay_constant_uncertainty
tau_b175_unc_F21 = one_over_e_time
tau_b175_unc_F21 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:43:26: on (Y-M-D) 2023-10-3, And ended at 17:10:14: on 2023-10-3
# Experiment Notes:
#
# gamma = 0.008721860541701704 gamma uncertainty = 0.0012199896272126244
# /var/folders/p1/sslzk5t517d2pwp06md4xf_w0000gn/T/ipykernel_1495/604109091.py:2: RuntimeWarning:
#
# overflow encountered in exp

# %% [markdown]
# # D1 F=2-2' Red

# %% [markdown]
# ## -600 MHz (DDS=185) ***

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 9
threshold = 100
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -600 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r600_F22 = decay_constant*2
gamma_r600_unc_F22 = decay_constant_uncertainty
tau_r600_F22 = one_over_e_time
tau_r600_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 13:7:29: on (Y-M-D) 2023-10-3, And ended at 13:34:22: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.010922505502638477 gamma uncertainty = 0.0034337048738258065
# /var/folders/p1/sslzk5t517d2pwp06md4xf_w0000gn/T/ipykernel_1495/604109091.py:2: RuntimeWarning:
#
# overflow encountered in exp

# %% [markdown]
# ## -500 MHz (DDS=179.18)

# %%
##pulse duration
reloadMyModules(3,'october')
fileId = 7
threshold = 90
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -500 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r500_F22 = decay_constant
gamma_r500_unc_F22 = decay_constant_uncertainty
tau_r500_F22 = one_over_e_time
tau_r500_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:23:21: on (Y-M-D) 2023-10-3, And ended at 9:50:15: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.010588619093160214 gamma uncertainty = 0.003254300692061189
# /var/folders/p1/sslzk5t517d2pwp06md4xf_w0000gn/T/ipykernel_1495/604109091.py:2: RuntimeWarning:
#
# overflow encountered in exp

# %% [markdown]
# ## -400 MHz (DDS=166.68)

# %%
##pulse duration
reloadMyModules(3,'October')
fileId = 6
threshold = 55
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -400 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r400_F22 = decay_constant
gamma_r400_unc_F22 = decay_constant_uncertainty
tau_r400_F22 = one_over_e_time
tau_r400_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:54:27: on (Y-M-D) 2023-10-3, And ended at 9:21:20: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.007613190887308953 gamma uncertainty = 0.003384498121280077
# /var/folders/p1/sslzk5t517d2pwp06md4xf_w0000gn/T/ipykernel_1495/604109091.py:2: RuntimeWarning:
#
# overflow encountered in exp

# %% [markdown]
# ## -300 MHz (DDS=154.18)

# %%
##pulse duration
reloadMyModules(3,'October')
fileId = 5
threshold = 75
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -300 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r300_F22 = decay_constant
gamma_r300_unc_F22 = decay_constant_uncertainty
tau_r300_F22 = one_over_e_time
tau_r300_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:30:15: on (Y-M-D) 2023-10-3, And ended at 8:53:8: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.008056526121026503 gamma uncertainty = 0.003931407484899386

# %% [markdown]
# ## -200 MHz (DDS=141.68)

# %%
##pulse duration
reloadMyModules(3,'October')
fileId = 3
threshold = 75
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -200 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r200_F22 = decay_constant
gamma_r200_unc_F22 = decay_constant_uncertainty
tau_r200_F22 = one_over_e_time
tau_r200_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 7:8:35: on (Y-M-D) 2023-10-3, And ended at 7:28:27: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.022845224442183825 gamma uncertainty = 0.00704931202964826

# %% [markdown]
# ## -150 MHz (DDS=135.3)

# %%
##pulse duration
reloadMyModules(3,'October')
fileId = 1
threshold = 85
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -150 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r150_F22 = decay_constant
gamma_r150_unc_F22 = decay_constant_uncertainty
tau_r150_F22 = one_over_e_time
tau_r150_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 6:24:57: on (Y-M-D) 2023-10-3, And ended at 6:45:47: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.03555300103543253 gamma uncertainty = 0.010048167492290726

# %% [markdown]
# ## -100 MHz (DDS=129.19)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 30
threshold = 62
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -100 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 

gamma_r100_F22 = decay_constant
gamma_r100_unc_F22 = decay_constant_uncertainty
tau_r100_F22 = one_over_e_time
tau_r100_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 22:11:25: on (Y-M-D) 2023-10-2, And ended at 22:30:14: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.06374827935984712 gamma uncertainty = 0.014743102643505573

# %% [markdown]
# ## -75 MHz (DDS=126.05)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 32
threshold = 75
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -75 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r75_F22 = decay_constant
gamma_r75_unc_F22 = decay_constant_uncertainty
tau_r75_F22 = one_over_e_time
tau_r75_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 22:54:38: on (Y-M-D) 2023-10-2, And ended at 23:15:31: on 2023-10-2
# Experiment Notes:
#
# gamma = 0.04084933286105843 gamma uncertainty = 0.007837447012867994

# %%
##pulse duration
reloadMyModules(10,'October')
fileId = 18
threshold = 75
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]

avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -75 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 

# gamma_r75_F22 = decay_constant
# gamma_r75_unc_F22 = decay_constant_uncertainty
# tau_r75_F22 = one_over_e_time
# tau_r75_unc_F22 = one_over_e_time_uncertainty
# print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 50;	Exp File Version: 4;
# Experiment started at (H:M:S) 14:11:24: on (Y-M-D) 2023-10-10, And ended at 14:14:44: on 2023-10-10
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.

# %% [markdown]
# ## -50 MHz (DDS=122.93)

# %%
##pulse duration
reloadMyModules(2,'October')
fileId = 31
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -50 \ \mathrm{MHz} \ \mathrm{D1 \ F=2-2} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r50_F22 = decay_constant
gamma_r50_unc_F22 = decay_constant_uncertainty
tau_r50_F22 = one_over_e_time
tau_r50_unc_F22 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 22:34:4: on (Y-M-D) 2023-10-2, And ended at 22:52:54: on 2023-10-2
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.025750938651826524 gamma uncertainty = 0.010635050301167405

# %% [markdown]
# # D2 F=2-3' Blue

# %% [markdown]
# ## 50 MHz (VCO=1.76)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 19
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:red'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
avgTferData1[6] = 0.2
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 50 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_b50_F23d2 = decay_constant
gamma_b50_unc_F23d2 = decay_constant_uncertainty
tau_b50_F23d2 = one_over_e_time
tau_b50_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 12:53:33: on (Y-M-D) 2023-10-4, And ended at 13:12:50: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.050709555061297214 gamma uncertainty = 0.015485213405231322

# %% [markdown]
# ## 100 MHz (VCO=1.76)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 20
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:red'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
avgTferData1[7] = 0.35
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 100 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_b100_F23d2 = decay_constant
gamma_b100_unc_F23d2 = decay_constant_uncertainty
tau_b100_F23d2 = one_over_e_time
tau_b100_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 13:52:27: on (Y-M-D) 2023-10-4, And ended at 14:11:45: on 2023-10-4
# Experiment Notes:
#
# gamma = 0.15126378299202553 gamma uncertainty = 0.05893133956586111

# %% [markdown]
# ## 150 MHz (VCO=2.36)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 22
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:red'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
avgTferData1[7] = 0.3
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 150 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_b150_F23d2 = decay_constant
gamma_b150_unc_F23d2 = decay_constant_uncertainty
tau_b150_F23d2 = one_over_e_time
tau_b150_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 14:24:2: on (Y-M-D) 2023-10-4, And ended at 14:43:19: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.07608719074403673 gamma uncertainty = 0.01955620767376292

# %% [markdown]
# ## 200 MHz (VCO=2.66)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 25
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:red'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 200 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_b200_F23d2 = decay_constant
gamma_b200_unc_F23d2 = decay_constant_uncertainty
tau_b200_F23d2 = one_over_e_time
tau_b200_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:15:28: on (Y-M-D) 2023-10-4, And ended at 16:35:46: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.053722907117786926 gamma uncertainty = 0.012188543742952395

# %% [markdown]
# ## 300 MHz (VCO=3.25)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 24
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:red'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = 300 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_b300_F23d2 = decay_constant
gamma_b300_unc_F23d2 = decay_constant_uncertainty
tau_b300_F23d2 = one_over_e_time
tau_b300_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 15:52:45: on (Y-M-D) 2023-10-4, And ended at 16:13:2: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.032332530611939775 gamma uncertainty = 0.005082375420046315

# %% [markdown]
# # D2 F=2-3' Red

# %% [markdown]
# ## -50 MHz (VCO=1.17)

# %%
##pulse duration
reloadMyModules(3,'October')
fileId = 22
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:red'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -50 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r50_F23d2 = decay_constant
gamma_r50_unc_F23d2 = decay_constant_uncertainty
tau_r50_F23d2 = one_over_e_time
tau_r50_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 23:6:35: on (Y-M-D) 2023-10-3, And ended at 23:25:51: on 2023-10-3
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.08058342052450064 gamma uncertainty = 0.023228471349851516

# %% [markdown]
# ## -62.5 MHz (VCO=1.09)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 1
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:red'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
avgTferData1[4] = 0.25

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -62.5 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r62_F23d2 = decay_constant
gamma_r62_unc_F23d2 = decay_constant_uncertainty
tau_r62_F23d2 = one_over_e_time
tau_r62_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 6:40:17: on (Y-M-D) 2023-10-4, And ended at 6:59:34: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.12772817582459545 gamma uncertainty = 0.018313096433083847

# %% [markdown]
# ## -75 MHz (VCO=1.023)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 4
threshold = 90
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:red'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -75 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r75_F23d2 = decay_constant
gamma_r75_unc_F23d2 = decay_constant_uncertainty
tau_r75_F23d2 = one_over_e_time
tau_r75_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 7:48:0: on (Y-M-D) 2023-10-4, And ended at 8:6:16: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.18646861342149595 gamma uncertainty = 0.060498419015633915

# %% [markdown]
# ## -87.5 MHz (VCO=0.949)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 3 #2
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
# avgTferData1[2] = 0.45
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -87 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r87_F23d2 = decay_constant
gamma_r87_unc_F23d2 = decay_constant_uncertainty
tau_r87_F23d2 = one_over_e_time
tau_r87_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 7:26:31: on (Y-M-D) 2023-10-4, And ended at 7:44:12: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.3400308872086511 gamma uncertainty = 0.12741403484683578

# %% [markdown]
# ## -100 MHz (VCO=0.874)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 2
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -100 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r100_F23d2 = decay_constant
gamma_r100_unc_F23d2 = decay_constant_uncertainty
tau_r100_F23d2 = one_over_e_time
tau_r100_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 7:0:28: on (Y-M-D) 2023-10-4, And ended at 7:18:21: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.3869267155654042 gamma uncertainty = 0.1065253478541262

# %% [markdown]
# ## -112.5 MHz (VCO=0.8)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 2
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -112.5 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r112_F23d2 = decay_constant
gamma_r112_unc_F23d2 = decay_constant_uncertainty
tau_r112_F23d2 = one_over_e_time
tau_r112_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 7:0:28: on (Y-M-D) 2023-10-4, And ended at 7:18:21: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.36573416716841917 gamma uncertainty = 0.10743883253461815

# %% [markdown]
# ## -125 MHz (VCO=0.726)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 10
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
avgTferData1[7] = 0.35

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -125 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r125_F23d2 = decay_constant
gamma_r125_unc_F23d2 = decay_constant_uncertainty
tau_r125_F23d2 = one_over_e_time
tau_r125_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:8:39: on (Y-M-D) 2023-10-4, And ended at 9:26:59: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.24360099646824696 gamma uncertainty = 0.0777240866172259

# %% [markdown]
# ## -150 MHz (VCO=0.577)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 8
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
avgTferData1[7] = 0.4
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -150 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r150_F23d2 = decay_constant
gamma_r150_unc_F23d2 = decay_constant_uncertainty
tau_r150_F23d2 = one_over_e_time
tau_r150_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:42:48: on (Y-M-D) 2023-10-4, And ended at 9:2:5: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.15823383606182392 gamma uncertainty = 0.06845354645769508

# %% [markdown]
# ## -200 MHz (VCO=0.279)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 7
threshold = 80
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
avgTferData1[6] = 0.3
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -200 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r200_F23d2 = decay_constant
gamma_r200_unc_F23d2 = decay_constant_uncertainty
tau_r100_F23d2 = one_over_e_time
tau_r200_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 8:22:25: on (Y-M-D) 2023-10-4, And ended at 8:41:19: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.08674631969317165 gamma uncertainty = 0.025563080336215217

# %% [markdown]
# ## -215 MHz (VCO=0.19) (50 blue of F=2-2')

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 11
threshold = 75
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8
# avgTferData1[7] = 0.4
x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -215 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r215_F23d2 = decay_constant
gamma_r215_unc_F23d2 = decay_constant_uncertainty
tau_r215_F23d2 = one_over_e_time
tau_r215_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:32:4: on (Y-M-D) 2023-10-4, And ended at 9:50:21: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.06633176459878076 gamma uncertainty = 0.018903923358108914

# %% [markdown]
# ## -265 MHz (VCO=0.19) (F=2-2' res)

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 17
threshold = 60
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -265 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r265_F23d2 = decay_constant
gamma_r265_unc_F23d2 = decay_constant_uncertainty
tau_r265_F23d2 = one_over_e_time
tau_r265_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 11:54:0: on (Y-M-D) 2023-10-4, And ended at 12:13:17: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.06429575444989476 gamma uncertainty = 0.014606491917272245

# %% [markdown]
# ## -315 MHz (VCO=-0.405) (50 red of F=2-2')

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 12
threshold = 65
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -315 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r315_F23d2 = decay_constant
gamma_r315_unc_F23d2 = decay_constant_uncertainty
tau_r315_F23d2 = one_over_e_time
tau_r315_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 9:53:48: on (Y-M-D) 2023-10-4, And ended at 10:13:6: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.08123404801405607 gamma uncertainty = 0.02982734510473816

# %% [markdown]
# ## -365 MHz (VCO=-0.702) (100 red of F=2-2')

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 13
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

# fig, ax = plt.subplots(figsize=(15, 6))
# font = {'family' : 'DejaVu Sans',
#         'weight' : 'normal',
#         'size'   : 22}
# matplotlib.rc('font', **font)
# decay_constant_str = f"{decay_constant:.4f}"
# decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
# legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
# ticks = np.arange(key1[0], max(key1),len(key1))
# ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
#             markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -365 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
# plt.plot(x_fit, y_fit, 'gray',label=legend_label)
# plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
# plt.ylim(0,1)
# plt.ylabel('survival')
# plt.xlabel(r'pulse duration (ms)')
# plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain') 


gamma_r365_F23d2 = decay_constant
gamma_r365_unc_F23d2 = decay_constant_uncertainty
tau_r365_F23d2 = one_over_e_time
tau_r365_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 10:24:48: on (Y-M-D) 2023-10-4, And ended at 10:44:5: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.13140232516658298 gamma uncertainty = 0.017600340849536315

# %% [markdown]
# ## -465 MHz (VCO=-1.29) (50 red of F=2-1' )

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 14
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -465 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r465_F23d2 = decay_constant
gamma_r465_unc_F23d2 = decay_constant_uncertainty
tau_r465_F23d2 = one_over_e_time
tau_r465_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 10:47:18: on (Y-M-D) 2023-10-4, And ended at 11:6:35: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.06745975820294613 gamma uncertainty = 0.019693115191879808

# %% [markdown]
# ## -495 MHz (VCO=-1.29)  F=2-0' res )

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 16
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -495 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r495_F23d2 = decay_constant
gamma_r495_unc_F23d2 = decay_constant_uncertainty
tau_r495_F23d2 = one_over_e_time
tau_r495_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 11:32:33: on (Y-M-D) 2023-10-4, And ended at 11:51:50: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.10382803922587192 gamma uncertainty = 0.027344655727808337

# %% [markdown]
# ## -545 MHz (VCO=-1.77) 50 red of F=2-0'  )

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 27
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -545 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r545_F23d2 = decay_constant
gamma_r545_unc_F23d2 = decay_constant_uncertainty
tau_r545_F23d2 = one_over_e_time
tau_r545_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 17:13:7: on (Y-M-D) 2023-10-4, And ended at 17:33:25: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.04719771773843921 gamma uncertainty = 0.007196278429713388

# %% [markdown]
# ## -595 MHz (VCO=-2.07) 100 red of F=2-0'

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 26
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -595 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r595_F23d2 = decay_constant
gamma_r595_unc_F23d2 = decay_constant_uncertainty
tau_r595_F23d2 = one_over_e_time
tau_r595_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 16:45:15: on (Y-M-D) 2023-10-4, And ended at 17:5:33: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.032812893152149795 gamma uncertainty = 0.006458425061236482

# %% [markdown]
# ## -695 MHz (VCO=-2.07) 200 red of F=2-0'

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 29
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -695 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r645_F23d2 = decay_constant
gamma_r645_unc_F23d2 = decay_constant_uncertainty
tau_r645_F23d2 = one_over_e_time
tau_r645_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 18:19:33: on (Y-M-D) 2023-10-4, And ended at 18:39:50: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.05303080540524549 gamma uncertainty = 0.03721901148517975

# %% [markdown]
# ## -645 MHz (VCO=-2.07) 100 red of F=2-0'

# %%
##pulse duration
reloadMyModules(4,'October')
fileId = 28
threshold = 70
dataset1 = ta.standardTransferAnalysis(fileId, loadTwoOpt, tOptions = [to.ThresholdOptions(manualThreshold = True, manualThresholdValue = threshold)]);
(tferAtomsVarAvg, tferAtomsVarErrs, loadAtomsVarAvg, initPicCounts, keyName, key1, repetitions, initThresholds, 
            fits, avgTferData1, avgTferErr1, avgFit, avgPics, genAvgs, genErrs, tferVarAvg, tferVarErr, initAtomImages, 
            tferAtomImages, tferPicCounts, tferThresholds, fitModules, basicInfoStr, ensembleHits, tOptions, analysisOpts,
            tferAtomsPs, tferAtomsPs, tferList, isAnnotated, hmm) = dataset1
color1 = 'tab:blue'
upperbound = []
lowerbound = []
for i in np.arange(0,len(avgTferErr1)):
    up = avgTferErr1[i][0]
    lo = avgTferErr1[i][1]
    upperbound.append(up)  
    lowerbound.append(lo)
err1= [upperbound,lowerbound]
avgTferData1[0] = 0.8

x_data = key1
y_data = avgTferData1
initial_guess = [max(y_data), 0.1, min(y_data)]
popt, pcov = curve_fit(decay_exponential, x_data, y_data, p0=initial_guess)
x_fit = np.linspace(min(x_data), max(x_data), 100)
y_fit = decay_exponential(x_fit, *popt)
decay_constant = popt[1]
decay_constant_uncertainty = np.sqrt(pcov[1, 1])
one_over_e_time = 1 / decay_constant
one_over_e_time_uncertainty = decay_constant_uncertainty / decay_constant

fig, ax = plt.subplots(figsize=(15, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
decay_constant_str = f"{decay_constant:.4f}"
decay_constant_uncertainty_str = f"{decay_constant_uncertainty:.4f}"
legend_label = fr"$\Gamma$ = {decay_constant_str} ± {decay_constant_uncertainty_str}, $\tau$ = {one_over_e_time:.4f} ± {one_over_e_time_uncertainty:.4f}"
ticks = np.arange(key1[0], max(key1),len(key1))
ax.errorbar(key1,avgTferData1, yerr=err1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5, label=r'$ \Delta(2 \rightarrow 0) = -645 \ \mathrm{MHz} \ \mathrm{D2 \ F=2-3} $')
plt.plot(x_fit, y_fit, 'gray',label=legend_label)
plt.legend(loc= 'upper right', ncol = 1,prop={'size': 15})
plt.ylim(0,1)
plt.ylabel('survival')
plt.xlabel(r'pulse duration (ms)')
plt.rcParams["axes.linewidth"] = 1.5
plt.ticklabel_format(style='plain') 


gamma_r645_F23d2 = decay_constant
gamma_r645_unc_F23d2 = decay_constant_uncertainty
tau_r645_F23d2 = one_over_e_time
tau_r645_unc_F23d2 = one_over_e_time_uncertainty
print('gamma =',decay_constant,'gamma uncertainty =',decay_constant_uncertainty)
# Out:
# Number of Pictures: 4800; Picture Dimensions: 5 x 10
# Variations: 8;	Repetitions: 300;	Exp File Version: 4;
# Experiment started at (H:M:S) 17:52:7: on (Y-M-D) 2023-10-4, And ended at 18:12:25: on 2023-10-4
# Experiment Notes: HDF5 NOT ANNOTATED: please call exp.Annotate() to annotate this file.
#
# gamma = 0.06794756675383352 gamma uncertainty = 0.01996445831444082

# %% [markdown]
# # rate plots

# %%
def betaCalc(gamma,trap_depth,T): 
    KelvinToJoules = 1.380648780669e-23
    lmbda = 850e-9
    w_0 = 0.7e-6 # beam waist (radius)
    U = trap_depth*KelvinToJoules # depth in Joules
    w_r = np.sqrt(4*U/(mc.Rb87_M*w_0**2))# Hz
    w_a = w_r / (np.sqrt(2)*w_0*np.pi/lmbda) # Hz
    # w_r = 135000*(2*np.pi)
    # w_a = 25000*(2*np.pi)
    w = (w_r**2 * w_a)**(1/3)
    V = ((2*np.pi*mc.k_B * T/(mc.Rb87_M*w**2))**(3/2))*1e6
    beta = gamma*1e3*2*np.sqrt(2)*V
    # print('beta',beta,w_r/(2*np.pi),w_a/(2*np.pi))
    return V

# %% [markdown]
# ## D1 rate plot

# %%
gamma_0_F21=0.005
gamma_0_F22 = 0.01
gamma_0_unc_F21=0.001
gamma_0_unc_F22 = 0.001
detuningF21 = [-300,-250,-200,-150,-100,-50,0,50,100,
               150]

detuningF22 = [-600-16,-500-16,-400-16,-300-16,-200-16,-150-16,-100-16,-75-16,-50-16,0,50,62.5,75,87.5,100,
               125,150,200,250]

detuningF22shift = [delta+816 for delta in (detuningF22)]
detuningD1 = [delta for delta in (detuningF21+detuningF22shift)]
detuning_valuesD1 = [-300,-200,-100,0,100,200,300,400,500,600,700,816,916,1016]
detuning_labelsD1 = ['-300','-200','-100','0','100','200','300','400','300','200','100','0',
                  '100','200']

decay_rateD1 = [gamma_r300_F21,gamma_r250_F21,gamma_r200_F21,gamma_r150_F21,gamma_r100_F21,gamma_r50_F21,
              gamma_0_F21,gamma_b50_F21, 
              gamma_b100_F21,gamma_b150_F21,gamma_r600_F22,
              gamma_r500_F22, gamma_r400_F22,gamma_r300_F22,gamma_r200_F22,gamma_r150_F22,gamma_r100_F22,gamma_r75_F22,
              gamma_r50_F22,gamma_0_F22, gamma_r50_F22,gamma_b62_F22,
              gamma_b75_F22,gamma_b87_F22,gamma_b100_F22,gamma_b125_F22,gamma_b150_F22,gamma_b200_F22,
              gamma_b300_F22]



decay_rate_uncD1 = [gamma_r300_unc_F21,gamma_r250_unc_F21,gamma_r200_unc_F21,gamma_r150_unc_F21,gamma_r100_unc_F21,gamma_r50_unc_F21,
              gamma_0_unc_F21,gamma_b50_unc_F21, 
              gamma_b100_unc_F21,gamma_b150_unc_F21,gamma_r600_unc_F22,
              gamma_r500_unc_F22, gamma_r400_unc_F22,gamma_r300_unc_F22,gamma_r200_unc_F22,gamma_r150_unc_F22,gamma_r100_unc_F22,gamma_r75_unc_F22,
              gamma_r50_unc_F22,gamma_0_unc_F22,gamma_r50_unc_F22,gamma_b62_unc_F22,
              gamma_b75_unc_F22,gamma_b87_unc_F22,gamma_b100_unc_F22,gamma_b125_unc_F22,gamma_b150_unc_F22,gamma_b200_unc_F22,
              gamma_b300_unc_F22]

decay_rate_error_barD1 = [decay_rate_uncD1,decay_rate_uncD1]

volume_cm3 = betaCalc(1,0.5e-3,30e-6)
betaD1 = [gamma*volume_cm3*1e3 for gamma in decay_rateD1]
beta_uncD1 = [gamma_unc*volume_cm3*1e3 for gamma_unc in decay_rate_uncD1]
beta_errorD1 = [beta_uncD1,beta_uncD1]

color1 = 'tab:blue'
fig, ax = plt.subplots(figsize=(20, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
ax.errorbar(detuningD1,betaD1, yerr=beta_errorD1,ls='none',ecolor=color1,marker = 'o',markersize = 10,
            markerfacecolor=color1,markeredgecolor='k',capsize=5)

# Use ScalarFormatter for the y-axis labels
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(False)
plt.gca().xaxis.set_major_formatter(formatter)
plt.axvline(x=0, color='grey', linestyle='--')
plt.axvline(x=816, color='grey', linestyle='--')
plt.axvline(x=400, color='grey', linestyle='--', alpha=0.3)
ax.ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))  # Adjust the scilimits as needed
plt.text(-60, 4.3e-12, r"$\mathrm{F=2 \rightarrow 1'}$", fontsize=20, color='grey')
plt.text(765, 4.3e-12, r"$\mathrm{F=2 \rightarrow 2'}$", fontsize=20, color='grey')
plt.xticks(detuning_valuesD1, detuning_labelsD1)
plt.ylabel(r'$ \beta \ \ \mathrm{(cm^3s^{-1})} $')
plt.xlabel(r'$\Delta_{2 \rightarrow 0} \ (\mathrm{MHz})$')
# plt.title('D1, U = 10 MHz, I = 3S') 
plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain')

# %% [markdown]
# ## D2 rate plot

# %%
print(np.shape(beta_errorD1))
# Out:
# (2, 33)

# %%
gamma_0_F23d2 = 0.01
gamma_0_unc_F23d2 = 0.001
gamma_0_F21d2 = .08
gamma_0_unc_F21d2 = .02

detuningF23 = [-595,-545,-495,-455,-415,-365,-315,-266,-200,-160,-125,-100,-75,-50,0,50,100,150,200,250]


detuningF23shift = [(delta) for delta in (detuningF23)]
detuningD2 = [delta for delta in (detuningF23shift)]

detuning_valuesD2 = [-595,-495,-455,-415,-340,-266,-200,-133,-66,0,100,200]
detuning_labelsD2 = ['-100','0','36','0','78','0','66','133','66','0','100','200']

decay_rateD2 = [gamma_r595_F23d2,gamma_r545_F23d2,gamma_r495_F23d2,gamma_r465_F23d2,gamma_0_F21d2,gamma_r365_F23d2,gamma_r315_F23d2,gamma_r265_F23d2,gamma_r200_F23d2,gamma_r150_F23d2,gamma_r125_F23d2,
              gamma_r100_F23d2,gamma_r75_F23d2,gamma_r50_F23d2,gamma_0_F23d2,gamma_b50_F23d2,gamma_b100_F23d2,gamma_b150_F23d2,
              gamma_b200_F23d2,gamma_b300_F23d2]



decay_rate_uncD2 = [gamma_r595_unc_F23d2,gamma_r545_unc_F23d2, gamma_r495_unc_F23d2,gamma_r465_unc_F23d2,gamma_0_unc_F21d2,gamma_r365_unc_F23d2,gamma_r315_unc_F23d2,gamma_r265_unc_F23d2,gamma_r200_unc_F23d2,
                  gamma_r150_unc_F23d2,gamma_r125_unc_F23d2, gamma_r100_unc_F23d2,gamma_r75_unc_F23d2,
                  gamma_r50_unc_F23d2,gamma_0_unc_F23d2,gamma_b50_unc_F23d2,gamma_b100_unc_F23d2,gamma_b150_unc_F23d2,gamma_b200_unc_F23d2,gamma_b300_unc_F23d2]

decay_rate_error_barD2 = [decay_rate_uncD2,decay_rate_uncD2]

volume_cm3 = betaCalc(1,0.5e-3,30e-6)
betaD2 = [gamma*volume_cm3*1e3 for gamma in decay_rateD2]
beta_uncD2 = [gamma_unc*volume_cm3*1e3 for gamma_unc in decay_rate_uncD2]
beta_errorD2 = [beta_uncD2,beta_uncD2]

color2 = 'tab:red'
fig, ax = plt.subplots(figsize=(20, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
ax.errorbar(detuningD2,betaD2, yerr=beta_errorD2,ls='none',ecolor=color2,marker = 'o',markersize = 10,
            markerfacecolor=color2,markeredgecolor='k',capsize=5)



##### log plot
# betaD2 = [gamma*volume_cm3*1e3+1 for gamma in decay_rateD2]
# beta_uncD2 = [gamma_unc*volume_cm3*1e3 for gamma_unc in decay_rate_uncD2]
# beta_errorD2 = [beta_uncD2,beta_uncD2]

# ax.errorbar(detuningD2,np.log(betaD2), yerr=beta_errorD2,ls='none',ecolor=color2,marker = 'o',markersize = 10,
#             markerfacecolor=color2,markeredgecolor='k',capsize=5)

# Use ScalarFormatter for the y-axis labels
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(False)
plt.gca().xaxis.set_major_formatter(formatter)
plt.axvline(x=-495, color='grey', linestyle='--')
plt.axvline(x=-415, color='grey', linestyle='--')
plt.axvline(x=-266, color='grey', linestyle='--')
plt.axvline(x=-0, color='grey', linestyle='--')
plt.axvline(x=0, color='grey', linestyle='--', alpha=0.3)
ax.ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))  # Adjust the scilimits as needed
plt.text(-545, 1.9e-11, r"$\mathrm{F=2 \rightarrow 0'}$", fontsize=20, color='grey')
plt.text(-310, 1.9e-11, r"$\mathrm{F=2 \rightarrow 2'}$", fontsize=20, color='grey')
plt.text(-450, 1.9e-11, r"$\mathrm{F=2 \rightarrow 1'}$", fontsize=20, color='grey')
plt.text(-30, 1.9e-11, r"$\mathrm{F=2 \rightarrow 3'}$", fontsize=20, color='grey')
plt.xticks(detuning_valuesD2, detuning_labelsD2)
plt.ylabel(r'$ \beta \ \ \mathrm{(cm^3s^{-1})} $')
plt.xlabel(r'$\Delta_{2 \rightarrow 0} \ \mathrm{MHz}$')
# plt.title('D1, U = 10 MHz, I = 3S') 
plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain')

# %%
print(detuningD1D2values)
print(len(detuningD1D2values))
# Out:
# [-595, -495, -455, -415, -340, -266, -200, -133, -66, 0, 100, 200, 350, 450, 550, 650, 750, 850, 950, 1050, 1150, 1250, 1350, 1466, 1566, 1666]
# 26

# %% [markdown]
# ## D2 and D2 rate plot

# %%
shiftVal = 650
detuningD1shifted = [delta+shiftVal for delta in detuningD1]
detuning_valuesD1shifted = [delta+780 for delta in detuning_valuesD1]
detuningD1D2 = [delta for delta in (detuningD2 + detuningD1shifted)]

detuningD2labels = ['-600','-400','-200','0','200']
detuningD1labels = ['-1000','-800','-600','-400','-200','0','200']
detuning_valuesD1shifted = [int(delta)+1468 for delta in detuningD1labels]


detuningD1D2labels = [delta for delta in detuningD2labels+detuningD1labels]
detuningD1D2values = [int(delta) for delta in (detuningD2labels+detuning_valuesD1shifted)]



betaD1D2 = [beta*1e11 for beta in (betaD2+betaD1)]
betaUncD1D2 = [beta_unc*1e11 for beta_unc in (beta_uncD2+beta_uncD1)]
betaErrorD1D2 = [betaUncD1D2,betaUncD1D2]

betaValues = [0,.5,1,1.5]
betaLabels = ['0',r'$0.5 \times 10^{-11}$',r'$1.0 \times 10^{-11}$',r'$1.5 \times 10^{-11}$']

color3 = 'tab:blue'
fig, ax = plt.subplots(figsize=(20, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
ax.errorbar(detuningD1D2,betaD1D2, yerr=betaErrorD1D2,ls='none',ecolor=color3,marker = 'o',markersize = 10,
            markerfacecolor=color3,markeredgecolor='k',capsize=5)

# Use ScalarFormatter for the y-axis labels
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(False)
plt.gca().xaxis.set_major_formatter(formatter)
plt.axvline(x=-495, color='grey', linestyle='--')
plt.axvline(x=-415, color='grey', linestyle='--')
plt.axvline(x=-266, color='grey', linestyle='--')
plt.axvline(x=-0, color='grey', linestyle='--')
plt.axvline(x=-266, color='grey', linestyle='--')
plt.axvline(x=1468, color='grey', linestyle='--')
plt.axvline(x=650, color='grey', linestyle='--')
plt.axvline(x=300, color='black', linestyle='-',alpha=0.8)
ax.ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))  # Adjust the scilimits as needed
ax.set_xlim(-650, 1700)
scaleVal=1
plt.text(-525, 1.9*scaleVal, r"$2,0'$", fontsize=15, color='grey')
plt.text(-290, 1.9*scaleVal, r"$2,2'$", fontsize=15, color='grey')
plt.text(-440, 1.9*scaleVal, r"$2,1'$", fontsize=15, color='grey')
plt.text(-30, 1.9*scaleVal, r"$ 2,3'$", fontsize=15, color='grey')
plt.text(620, 1.9*scaleVal, r"$2,1'$", fontsize=15, color='grey')
plt.text(1440, 1.9*scaleVal, r"$2,2'$", fontsize=15, color='grey')
plt.text(180, 1.3*scaleVal, r"$\leftarrow \ \mathrm{D2}$", fontsize=15, color='black')
plt.text(320, 1.3*scaleVal, r"$ \mathrm{D1} \ \rightarrow $", fontsize=15, color='black')
plt.xticks(detuningD1D2values, detuningD1D2labels)
# plt.yticks(betaValues, betaLabels)
plt.ylabel(r'$ \beta  \ \mathrm{(cm^3s^{-1})} \times 10^{-11}$')
plt.xlabel(r'$\Delta_{2 \rightarrow 0} \ (\mathrm{MHz})$')
# plt.title('D1, U = 10 MHz, I = 3S') 
plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain')

# %% [markdown]
# ## D2 and D2 rate plot log scale

# %%
detuningD1shifted = [delta+650 for delta in detuningD1]
detuning_valuesD1shifted = [delta+650 for delta in detuning_valuesD1]
detuningD1D2 = [delta for delta in (detuningD2 + detuningD1shifted)]

detuningD2labels = ['-600','-400','-200','0','200']
detuningD1labels = ['-1000','-800','-600','-400','-200','0','200']
detuning_valuesD1shifted = [int(delta)+1468 for delta in detuningD1labels]


detuningD1D2labels = [delta for delta in detuningD2labels+detuningD1labels]
detuningD1D2values = [int(delta) for delta in (detuningD2labels+detuning_valuesD1shifted)]



betaD1D2 = [beta+1 for beta in (betaD2+betaD1)]
betaUncD1D2 = [beta_unc for beta_unc in (beta_uncD2+beta_uncD1)]
betaErrorD1D2 = [betaUncD1D2,betaUncD1D2]

betaValues = [-4,-3,-2,-1,0]
betaLabels = ['0',r'$0.5 \times 10^{-11}$',r'$1.0 \times 10^{-12}$',r'10^{-11}$']

color3 = 'tab:blue'
fig, ax = plt.subplots(figsize=(20, 6))
font = {'family' : 'DejaVu Sans',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)
ax.errorbar(detuningD1D2,np.log(betaD1D2), yerr=betaErrorD1D2,ls='none',ecolor=color3,marker = 'o',markersize = 10,
            markerfacecolor=color3,markeredgecolor='k',capsize=5)

# Use ScalarFormatter for the y-axis labels
ax.yaxis.set_major_formatter(ScalarFormatter(useMathText=True))
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(False)
plt.gca().xaxis.set_major_formatter(formatter)
plt.axvline(x=-495, color='grey', linestyle='--')
plt.axvline(x=-415, color='grey', linestyle='--')
plt.axvline(x=-266, color='grey', linestyle='--')
plt.axvline(x=-0, color='grey', linestyle='--')
plt.axvline(x=-266, color='grey', linestyle='--')
plt.axvline(x=1468, color='grey', linestyle='--')
plt.axvline(x=650, color='grey', linestyle='--')
plt.axvline(x=300, color='black', linestyle='-',alpha=0.8)
# ax.ticklabel_format(axis='y', style='sci', scilimits=(-3, 3))  # Adjust the scilimits as needed
ax.set_xlim(-650, 1700)
ax.set_yscale('log')

scaleVal=1.3e-11
plt.text(-525, 1.9*scaleVal, r"$2,0'$", fontsize=15, color='grey')
plt.text(-290, 1.9*scaleVal, r"$2,2'$", fontsize=15, color='grey')
plt.text(-440, 1.9*scaleVal, r"$2,1'$", fontsize=15, color='grey')
plt.text(-30, 1.9*scaleVal, r"$ 2,3'$", fontsize=15, color='grey')
plt.text(620, 1.9*scaleVal, r"$2,1'$", fontsize=15, color='grey')
plt.text(1440, 1.9*scaleVal, r"$2,2'$", fontsize=15, color='grey')
plt.text(180, 1.3*scaleVal, r"$\leftarrow \ \mathrm{D2}$", fontsize=15, color='black')
plt.text(320, 1.3*scaleVal, r"$ \mathrm{D1} \ \rightarrow $", fontsize=15, color='black')
plt.xticks(detuningD1D2values, detuningD1D2labels)
# plt.yticks(betaValues, betaLabels)
plt.ylabel(r'$ \beta  \ \mathrm{(cm^3s^{-1})}$')
plt.xlabel(r'$\Delta_{2 \rightarrow 0} \ (\mathrm{MHz})$')
# plt.title('D1, U = 10 MHz, I = 3S') 
plt.rcParams["axes.linewidth"] = 1.5
# plt.ticklabel_format(style='plain')
